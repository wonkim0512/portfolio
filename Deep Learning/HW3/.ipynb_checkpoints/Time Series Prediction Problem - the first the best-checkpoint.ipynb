# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
np.random.seed(11)

# %% [markdown]
# > raw data

# %%
raw_data = pd.read_csv('raw.csv').set_index("Date")

# %%
first_two_years = raw_data[:730]
first_two_years.tail()
# Out:
#             Value
# Date
# 1982-12-27   15.3
# 1982-12-28   16.3
# 1982-12-29   15.8
# 1982-12-30   17.7
# 1982-12-31   16.3

# %%
plt.figure(figsize = (15, 10))
plt.plot(list(range(730)), first_two_years.Value)
plt.show()

# %%
min(raw_data.Value), max(raw_data.Value)
# Out:
# (0.0, 26.3)

# %% [markdown]
# > training data & validation data

# %%
# 10 years data
data = pd.read_csv('train.csv')
data = data.set_index("Date")

# %%
# 9 years data for training
train_data = data[: -365]
train_X = train_data.iloc[:, :6].as_matrix()
train_Y = train_data.iloc[:, 6:].as_matrix()
train_X.shape, train_Y.shape
# Out:
# ((2914, 6), (2914, 1))

# %%
# 1 year data for validation
validation_data = data[-365:]
valid_X = validation_data.iloc[:, :6].as_matrix()
valid_Y = validation_data.iloc[:, 6:].as_matrix()
valid_X.shape, valid_Y.shape
# Out:
# ((365, 6), (365, 1))

# %% [markdown]
# > test data

# %%
test_data = pd.read_csv('test.csv')
test_data = test_data.set_index('Date')
test_data = test_data.as_matrix()
test_data.shape
# Out:
# (52, 6)

# %% [markdown]
# > model

# %%
timesteps = 6
data_dim = 1
output_dim = 1
learning_rate = 0.001
training_epoch = 1000

# %%
X = tf.placeholder(tf.float32, [None, timesteps, data_dim])
Y = tf.placeholder(tf.float32, [None, output_dim])

# %%
cell = tf.contrib.rnn.BasicLSTMCell(num_units = 128, state_is_tuple = True)
outputs, _states = tf.nn.dynamic_rnn(cell, X, dtype = tf.float32)

# %%
Y_pred = tf.contrib.layers.fully_connected(outputs[:, -1], output_dim, activation_fn = None)
loss = tf.reduce_mean(tf.square(Y_pred - Y))

# %% [markdown]
# > learning_rate = 0.001

# %%
optimizer = tf.train.AdamOptimizer(learning_rate)
train = optimizer.minimize(loss)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %%
reshaped_train_X = train_X.reshape((*train_X.shape, 1))

for epoch in range(training_epoch):
    value, l = sess.run([train, loss], feed_dict = {X: reshaped_train_X, Y: train_Y})
    if epoch % 50 == 0:
        print(epoch,'RMSE = ', np.sqrt(l), 'value = ', value)

validPrediction = sess.run(Y_pred, feed_dict = {X: valid_X.reshape((*valid_X.shape, 1))})
sess.close()
# Out:
# 0 RMSE =  11.4543 value =  None
# 50 RMSE =  3.97465 value =  None
# 100 RMSE =  3.20525 value =  None
# 150 RMSE =  2.75706 value =  None
# 200 RMSE =  2.60477 value =  None
# 250 RMSE =  2.54624 value =  None
# 300 RMSE =  2.51519 value =  None
# 350 RMSE =  2.4984 value =  None
# 400 RMSE =  2.48677 value =  None
# 450 RMSE =  2.4767 value =  None
# 500 RMSE =  2.46786 value =  None
# 550 RMSE =  2.45989 value =  None
# 600 RMSE =  2.4526 value =  None
# 650 RMSE =  2.44631 value =  None
# 700 RMSE =  2.44079 value =  None
# 750 RMSE =  2.436 value =  None
# 800 RMSE =  2.43121 value =  None
# 850 RMSE =  2.42659 value =  None
# 900 RMSE =  2.42167 value =  None
# 950 RMSE =  2.4162 value =  None

# %%
plt.figure(figsize = (15, 10))
plt.plot(valid_Y)
plt.plot(validPrediction)
plt.show()

# %% [markdown]
# > learning_rate = 0.005

# %%
learning_rate = 0.005
optimizer = tf.train.AdamOptimizer(learning_rate)
train = optimizer.minimize(loss)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %%
reshaped_train_X = train_X.reshape((*train_X.shape, 1))

for epoch in range(training_epoch):
    _, l = sess.run([train, loss], feed_dict = {X: reshaped_train_X, Y: train_Y})
    if epoch % 50 == 0:
        print(epoch,'RMSE = ', np.sqrt(l))

validPrediction = sess.run(Y_pred, feed_dict = {X: valid_X.reshape((*valid_X.shape, 1))})
sess.close()
# Out:
# 0 RMSE =  11.8736
# 50 RMSE =  3.58547
# 100 RMSE =  2.61417
# 150 RMSE =  2.52308
# 200 RMSE =  2.50813
# 250 RMSE =  2.48906
# 300 RMSE =  2.48273
# 350 RMSE =  2.4756
# 400 RMSE =  2.47145
# 450 RMSE =  2.46662
# 500 RMSE =  2.46289
# 550 RMSE =  2.46418
# 600 RMSE =  2.45412
# 650 RMSE =  2.45055
# 700 RMSE =  2.44504
# 750 RMSE =  2.4424
# 800 RMSE =  2.43649
# 850 RMSE =  2.42975
# 900 RMSE =  2.41813
# 950 RMSE =  2.41674

# %%
plt.figure(figsize = (15, 10))
plt.plot(valid_Y)
plt.plot(validPrediction)
plt.show()
