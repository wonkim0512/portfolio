# %%
import numpy as np
import pandas as pd
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle

# %%
df = pd.read_csv("maryland_accident_dataset_by_report_no.csv")
df.tail()
# Out:
#          REPORT_NO CDL_FLAG  \
# 29588  MCP2526000L        N
# 29589   AC2051000K        N
# 29590   ADI5630003        N
# 29591   HM0146000D        N
# 29592  MCP1519000S        N
#
#                                           CONDITION_CODE  EQUIP_PROB_CODE  \
# 29588                                  Apparently Asleep        No Misuse
# 29589  Influenced by Medications and/or Drugs and/or ...        No Misuse
# 29590  Influenced by Medications and/or Drugs and/or ...        No Misuse
# 29591  Influenced by Medications and/or Drugs and/or ...        No Misuse
# 29592  Influenced by Medications and/or Drugs and/or ...  Belt(s) Misused
#
#       FAULT_FLAG                  INJ_SEVER_CODE  \
# 29588          Y  Possible Incapacitating Injury
# 29589          Y                       No Injury
# 29590          Y                       No Injury
# 29591          Y                       No Injury
# 29592          Y  Possible Incapacitating Injury
#
#                                   PERSON_ID PERSON_TYPE        SAF_EQUIP_CODE  \
# 29588  e0715157-51da-4266-bfeb-9dbb80117fba           D  Shoulder/Lap Belt(s)
# 29589  15f07506-e12b-4b2a-aa31-44635150d1c2           D  Shoulder/Lap Belt(s)
# 29590  63529935-542d-4c69-af1f-1b3e49894090           D  Shoulder/Lap Belt(s)
# 29591  400dc255-6c26-4e47-9f75-920439556f0b           D  Shoulder/Lap Belt(s)
# 29592  6dbbc5b4-3922-4726-ae9f-d4140e986ea4           D  Shoulder/Lap Belt(s)
#
#       SEX_CODE                            VEHICLE_ID      COLLISION_TYPE_CODE  \
# 29588        M  40840738-5b3e-4c2f-b56c-430b6e2875a6          Single Vehicle
# 29589        M  fbbdb263-5979-4a02-bf49-88a840fd8e2e          Single Vehicle
# 29590        M  acfa1fcd-e286-4e64-ba2b-36894375ccc8  Same Direction Rear End
# 29591        M  1075765b-229c-478a-8d42-b4d41ec35309          Single Vehicle
# 29592        M  cec5b365-1040-4898-8943-fa9259c1189c          Single Vehicle
#
#       C_M_ZONE_FLAG     JUNCTION_CODE          LANE_CODE      LIGHT_CODE  \
# 29588             N      Intersection  Acceleration Lane        Daylight
# 29589             N  Non Intersection    Right Turn Lane  Dark Lights On
# 29590             N  Non Intersection  Acceleration Lane            Dusk
# 29591             N  Non Intersection    Right Turn Lane  Dark No Lights
# 29592             N  Non Intersection    Right Turn Lane  Dark Lights On
#
#                  RD_COND_CODE  \
# 29588              No Defects
# 29589              No Defects
# 29590              No Defects
# 29591  Loose Surface Material
# 29592              No Defects
#
#                                              RD_DIV_CODE     SURF_COND_CODE  \
# 29588                               Two-way, Not Divided                Dry
# 29589  Two-way, Divided, Unprotected (painted >4 feet...                Dry
# 29590          Two-way, Divided, Positive Median Barrier                Dry
# 29591                               Two-way, Not Divided  Mud, Dirt, Gravel
# 29592          Two-way, Divided, Positive Median Barrier                Dry
#
#       WEATHER_CODE AREA_DAMAGED_CODE_MAIN           BODY_TYPE_CODE  \
# 29588        Clear            One o'clock            Passenger Car
# 29589        Clear            One o'clock            Passenger Car
# 29590        Clear            One o'clock  (Sport) Utility Vehicle
# 29591        Clear            One o'clock  (Sport) Utility Vehicle
# 29592        Clear         Twelve o'clock            Passenger Car
#
#        DAMAGE_CODE HIT_AND_RUN_FLAG          MOVEMENT_CODE  \
# 29588    Disabling                N  Moving Constant Speed
# 29589    Disabling                N  Moving Constant Speed
# 29590  Superficial                N    Slowing or Stopping
# 29591    Disabling                Y  Moving Constant Speed
# 29592    Disabling                N  Moving Constant Speed
#
#                       TIME   AGE
# 29588  2015-11-15 15:34:00  28.0
# 29589  2015-12-19 22:40:00  42.0
# 29590  2015-10-22 18:00:00  51.0
# 29591  2015-11-29 22:45:00  26.0
# 29592  2015-12-03 02:42:00  45.0

# %%
df.columns
# Out:
# Index(['REPORT_NO', 'CDL_FLAG', 'CONDITION_CODE', 'EQUIP_PROB_CODE',
#        'FAULT_FLAG', 'INJ_SEVER_CODE', 'PERSON_ID', 'PERSON_TYPE',
#        'SAF_EQUIP_CODE', 'SEX_CODE', 'VEHICLE_ID', 'COLLISION_TYPE_CODE',
#        'C_M_ZONE_FLAG', 'JUNCTION_CODE', 'LANE_CODE', 'LIGHT_CODE',
#        'RD_COND_CODE', 'RD_DIV_CODE', 'SURF_COND_CODE', 'WEATHER_CODE',
#        'AREA_DAMAGED_CODE_MAIN', 'BODY_TYPE_CODE', 'DAMAGE_CODE',
#        'HIT_AND_RUN_FLAG', 'MOVEMENT_CODE', 'TIME', 'AGE'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
person_damage_type = df[['INJ_SEVER_CODE']].groupby(df['INJ_SEVER_CODE']).count()
person_damage_type.rename(columns = {'INJ_SEVER_CODE':'Count'})
# Out:
#                                 Count
# INJ_SEVER_CODE
# Fatal Injury                       26
# Incapacitating/Disabled Injury    239
# No Injury                       24451
# Non-incapacitating Injury        1751
# Possible Incapacitating Injury   3126

# %%
fig1 = person_damage_type.plot.bar()
fig1.set_ylabel("Count")
plt.show()

# %% [markdown]
# > Fatal injury, Incapacitating/Disabled Injury를 줄일 수 있는 방안을 찾아보자

# %%
vehicle_damage_type = df[['DAMAGE_CODE']].groupby(df['DAMAGE_CODE']).count()
vehicle_damage_type.rename(columns = {'DAMAGE_CODE':'Count'})
# Out:
#              Count
# DAMAGE_CODE
# Destroyed     1786
# Disabling    12413
# Functional    7777
# No Damage      742
# Superficial   6875

# %%
fig2 = vehicle_damage_type.plot.bar()
fig2.set_ylabel("Count")
plt.show()

# %% [markdown]
# > 사람의 부상정도와 차량의 파손정도는 다른 양상을 보인다. 차는 크게 파손되었지만 사람은 별로 다치지 않은 경우가 많다.
# 물론 현재 데이터에 '운전자' 정보만 들어가 있으므로 보행자 부상 여부는 알 수 없다. 하지만 안전벨트, 차량의 충격 흡수 등에 따라 운전자는 상대적으로 안전하게 보호받는 것을 알 수 있다.

# %%
no_injury_df = df[df["INJ_SEVER_CODE"] == "No Injury"]
fatal_df = df[(df["INJ_SEVER_CODE"] == "Fatal Injury")]
disabled_df = df[df["INJ_SEVER_CODE"] == "Incapacitating/Disabled Injury"]
non_incapacitating_df = df[df["INJ_SEVER_CODE"] == "Non-incapacitating Injury"]
possible_df = df[(df["INJ_SEVER_CODE"] == "Possible Incapacitating Injury")]

# %%
want_to_visualize = [
 'CONDITION_CODE',
 'EQUIP_PROB_CODE',
 'SAF_EQUIP_CODE',
 'COLLISION_TYPE_CODE',
 'C_M_ZONE_FLAG',
 'JUNCTION_CODE',
 'LANE_CODE',
 'LIGHT_CODE',
 'RD_COND_CODE',
 'RD_DIV_CODE',
 'SURF_COND_CODE',
 'WEATHER_CODE',
 'AREA_DAMAGED_CODE_MAIN',
 'BODY_TYPE_CODE',
 'DAMAGE_CODE',
 'MOVEMENT_CODE']

# %%
for col in want_to_visualize:
    #total_surf_type = df[[col]].groupby(df[col]).count()
    #total_surf_type.plot.bar()
    #plt.title("Total")

    no_injury_surf_type = no_injury_df[[col]].groupby(df[col]).count()
    no_injury_surf_type.plot.bar()
    plt.title("No Injury")

    fatal_surf_type = fatal_df[[col]].groupby(df[col]).count()
    fatal_surf_type.plot.bar()
    plt.title("Fatal")

    #possible_surf_type = possible_df[[col]].groupby(df[col]).count()
    #possible_surf_type.plot.bar()
    #plt.title("Possible")
    plt.show()
    print("*"*120)
# Out:
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************
# ************************************************************************************************************************

# %% [markdown]
# # 아래의 변수들이 차이를 보이는 것으로 나타남

# %%
important = ['CONDITION_CODE', 'INJ_SEVER_CODE', 
       'SAF_EQUIP_CODE', 'COLLISION_TYPE_CODE', 'SURF_COND_CODE', 'WEATHER_CODE',
       'AREA_DAMAGED_CODE_MAIN', 'BODY_TYPE_CODE', 'DAMAGE_CODE', 'AGE']

# %% [markdown]
# # Preprocessing

# %% [markdown]
# > 분석에 사용할 변수를 선택하는 작업은 자의적이다. 도메인 전문가가 아니므로 보건복지부 자료를 바탕으로 변수를 분류, 선택해보았다.
#
# - 첫번째, 사람에 의한 원인
#  - (1) 음주운전
#  - (2) 졸음 및 피로운전
#  - (3) 기타 요인 (약물복용 중 사고나, 운전 중 기존 질환의 악화나 발생으로 인한 사고)
#  - (4) 기타...
#
#
# - 두번째, 보호 장구 미착용 요인
#  - (1) 안전벨트 착용
#  - (2) 에어백
#  - (3) 안전의자
#  - (4) 헬멧 착용
#  - (5) 기타...
#
#
# - 세번째, 환경적 요인
#  - (1) 날씨
#  - (2) 노면상태
#  - (3) 기타...

# %% [markdown]
# # 비슷한 항목 합치기

# %% [markdown]
# # INJ_SEVER_CODE :
#  ['No Injury' 'Possible Incapacitating Injury' 'Non-incapacitating Injury'
#  'Incapacitating/Disabled Injury' 'Fatal Injury']

# %%
inj_type = df["INJ_SEVER_CODE"].copy()

inj_type[df['INJ_SEVER_CODE'] == "No Injury"] = 1
inj_type[df['INJ_SEVER_CODE'] == "Non-incapacitating Injury"] = 3
inj_type[df['INJ_SEVER_CODE'] == "Possible Incapacitating Injury"] = 8
inj_type[df['INJ_SEVER_CODE'] == "Incapacitating/Disabled Injury"] = 15
inj_type[df['INJ_SEVER_CODE'] == "Fatal Injury"] = 30


df['INJ_SEVER_CODE'] = inj_type
df["INJ_SEVER_CODE"].unique()
# Out:
# array([1, 8, 3, 15, 30], dtype=object)

# %% [markdown]
# # EQUIP_PROB_CODE :
#  ['No Misuse' 'Belt(s) Misused' 'Air Bag Failed' 'Facing Wrong Way'
#  'Not Strapped Right' 'Size/Type Improper' 'Not Anchored Right'
#  'Belts/Anchors Broken']

# %%
equip_prob_type = df["EQUIP_PROB_CODE"].copy()
equip_prob_type[df['EQUIP_PROB_CODE'] != "No Misuse"] = "Misuse"

df['EQUIP_PROB_CODE'] = equip_prob_type
df["EQUIP_PROB_CODE"].unique()
# Out:
# array(['No Misuse', 'Misuse'], dtype=object)

# %% [markdown]
# ## damaged_area

# %%
damaged_area = df["AREA_DAMAGED_CODE_MAIN"].copy()

damaged_area[df['AREA_DAMAGED_CODE_MAIN'] == "Six o'clock"] = 'Rear'
damaged_area[(df['AREA_DAMAGED_CODE_MAIN'] == "Twelve o'clock") | (df['AREA_DAMAGED_CODE_MAIN'] == "Eleven o'clock")\
             | (df['AREA_DAMAGED_CODE_MAIN'] == "One o'clock")] = 'Front'

damaged_area[(df['AREA_DAMAGED_CODE_MAIN'] != "Six o'clock") &(df['AREA_DAMAGED_CODE_MAIN'] != "Twelve o'clock") &\
             (df['AREA_DAMAGED_CODE_MAIN'] != "Eleven o'clock") & (df['AREA_DAMAGED_CODE_MAIN'] != "One o'clock")] = 'Side'

df['AREA_DAMAGED_CODE_MAIN'] = damaged_area
df["AREA_DAMAGED_CODE_MAIN"].unique()
# Out:
# array(['Rear', 'Front', 'Side'], dtype=object)

# %% [markdown]
# ## Condition code

# %%
condition_df = df['CONDITION_CODE'].copy()

condition_df[(df['CONDITION_CODE'] == 'Had Been Drinking') | (df['CONDITION_CODE'] == 'Using Drugs')|\
   (df['CONDITION_CODE'] == 'Influenced by Medications and/or Drugs and/or Alcohol')] = "Alchol/Drug"

condition_df[(df['CONDITION_CODE'] == 'Apparently Asleep') | (df['CONDITION_CODE'] == 'Fatigued Fainted')] = "Asleep"
condition_df[(df['CONDITION_CODE'] == 'Physical Defects')] = "Other Handicaps"

df["CONDITION_CODE"] = condition_df
df["CONDITION_CODE"].unique()
# Out:
# array(['Apparently Normal', 'Alchol/Drug', 'Other Handicaps', 'Ill',
#        'Asleep', 'Emotional Depressed Angry Disturbed'], dtype=object)

# %% [markdown]
# ## Equipment code

# %%
df['SAF_EQUIP_CODE'].unique()
# Out:
# array(['Shoulder/Lap Belt(s)', 'Shoulder Belt Only', 'Lap Belt Only',
#        'None  ', 'Child Restraint System Forward Facing',
#        'MC/Bike Helmet and Eye Protection', 'MC/Bike Helmet',
#        'MC/Bike Eye Protection Only', 'Lighting',
#        'Child Restraint Type Unknown'], dtype=object)

# %%
equip_df = df['SAF_EQUIP_CODE'].copy()

equip_df[(df['SAF_EQUIP_CODE'] == 'Shoulder/Lap Belt(s)') | (df['SAF_EQUIP_CODE'] =='Shoulder Belt Only') |\
         (df['SAF_EQUIP_CODE'] =='Lap Belt Only')] = "Belt"

equip_df[(df['SAF_EQUIP_CODE'] == 'Child Restraint System Forward Facing') | \
         (df['SAF_EQUIP_CODE'] =='Child Restraint Type Unknown')] = "Child System"

equip_df[(df['SAF_EQUIP_CODE'] == 'MC/Bike Helmet and Eye Protection') | (df['SAF_EQUIP_CODE'] =='MC/Bike Eye Protection Only') |\
         (df['SAF_EQUIP_CODE'] =='MC/Bike Helmet')] = "MC/Bike"

df['SAF_EQUIP_CODE'] = equip_df
df['SAF_EQUIP_CODE'].unique()
# Out:
# array(['Belt', 'None  ', 'Child System', 'MC/Bike', 'Lighting'], dtype=object)

# %% [markdown]
# ## COLLISION_TYPE_CODE
#  ['Same Direction Rear End Left Turn' 'Same Direction Rear End'
#  'Same Direction Sideswipe' 'Opposite Direction Both Left Turn'
#  'Opposite Direction Sideswipe' 'Same Movement Angle' 'Head On'
#  'Single Vehicle ' 'Same Direction Right Turn' 'Head On Left Turn'
#  'Same Direction Left Turn' 'Angle Meets Left Turn'
#  'Same Direction Rear End Right Turn' 'Angle Meets Left Turn Head On'
#  'Same Direction Both Left Turn' 'Angle Meets Right Turn']

# %%
collision_df = df['COLLISION_TYPE_CODE'].copy()

collision_df[(df['COLLISION_TYPE_CODE'] == 'Same Direction Rear End Left Turn') | (df['COLLISION_TYPE_CODE'] =='Same Direction Rear End Right Turn') |\
         (df['COLLISION_TYPE_CODE'] =='Same Direction Rear End')] = "Same Direction Rear End"
collision_df[(df['COLLISION_TYPE_CODE'] == 'Opposite Direction Both Left Turn') | (df['COLLISION_TYPE_CODE'] =='Opposite Direction Sideswipe')] = "Opposite Direction"
collision_df[(df['COLLISION_TYPE_CODE'] == 'Angle Meets Right Turn') | (df['COLLISION_TYPE_CODE'] =='Angle Meets Left Turn Head On')|\
            (df['COLLISION_TYPE_CODE'] =='Angle Meets Left Turn')] = "Angle Meets"
collision_df[(df['COLLISION_TYPE_CODE'] == 'Head On') | (df['COLLISION_TYPE_CODE'] =='Head On Left Turn')] = "Head On"
collision_df[(df['COLLISION_TYPE_CODE'] == 'Same Direction Right Turn') | (df['COLLISION_TYPE_CODE'] =='Same Direction Left Turn')|\
            (df['COLLISION_TYPE_CODE'] =='Same Direction Both Left Turn')] = "Same Direction/Turn"

df['COLLISION_TYPE_CODE'] = collision_df
df['COLLISION_TYPE_CODE'].unique()
# Out:
# array(['Same Direction Rear End', 'Same Direction Sideswipe',
#        'Opposite Direction', 'Same Movement Angle', 'Head On',
#        'Single Vehicle ', 'Same Direction/Turn', 'Angle Meets'], dtype=object)

# %% [markdown]
# ### BODY_TYPE_CODE
#  ['Passenger Car' '(Sport) Utility Vehicle' 'Pickup Truck'
#  'Other Light Trucks (10,000 lbs (4,536 kg))' 'Van' 'Other Bus'
#  'School Bus' 'Snowmobile' 'Station Wagon'
#  'Cargo Van/Light Truck 2 axles (10,000 lbs (4,536 kg) or less)'
#  'All Terrain Vehicle (ATV)' 'Police Vehicle/Non Emergency'
#  'Police Vehicle/Emergency' 'Transit Bus'
#  'Medium/Heavy Truck 2 axles (10,000 lbs (4,536 kg) or less)'
#  'Recreational Vehicle' 'Ambulance/Non Emergency' 'Low Speed Vehicle'
#  'Ambulance/Emergency' 'Truck Tractor' 'Fire Vehicle/Emergency'
#  'Farm Vehicle' 'Motorcycle' 'Fire Vehicle/Non Emergency' 'Limousine'
#  'Moped' 'Cross Country Bus']

# %%
body_df = df['BODY_TYPE_CODE'].copy()

body_df[(df['BODY_TYPE_CODE'] == '(Sport) Utility Vehicle') | (df['BODY_TYPE_CODE'] == 'Van')| (df['BODY_TYPE_CODE'] == 'Limousine')|\
       (df['BODY_TYPE_CODE'] == 'Station Wagon')] = "Passenger Car"
body_df[(df['BODY_TYPE_CODE'] == 'Pickup Truck') | (df['BODY_TYPE_CODE'] =='Other Light Trucks (10,000 lbs (4,536 kg))' ) |\
         (df['BODY_TYPE_CODE'] =='Cargo Van/Light Truck 2 axles (10,000 lbs (4,536 kg) or less)' )|\
        (df['BODY_TYPE_CODE'] =='Medium/Heavy Truck 2 axles (10,000 lbs (4,536 kg) or less)')] = "Truck"
body_df[(df['BODY_TYPE_CODE'] == 'Other Bus') | (df['BODY_TYPE_CODE'] =='School Bus' ) |\
         (df['BODY_TYPE_CODE'] =='Transit Bus' )|(df['BODY_TYPE_CODE'] =='Cross Country Bus' )|\
        (df['BODY_TYPE_CODE'] =='Medium/Heavy Truck 2 axles (10,000 lbs (4,536 kg) or less)')] = "Bus"
body_df[(df['BODY_TYPE_CODE'] == 'Police Vehicle/Emergency') | (df['BODY_TYPE_CODE'] =='Ambulance/Emergency' ) |\
         (df['BODY_TYPE_CODE'] =='Fire Vehicle/Emergency' )] = "Special/Emergency"
body_df[(df['BODY_TYPE_CODE'] == 'Police Vehicle/Non Emergency') | (df['BODY_TYPE_CODE'] =='Ambulance/Non Emergency' ) |\
         (df['BODY_TYPE_CODE'] =='Fire Vehicle/Non Emergency' )] = "Special/Non Emergency"
body_df[(df['BODY_TYPE_CODE'] == 'All Terrain Vehicle (ATV)') | (df['BODY_TYPE_CODE'] =='Recreational Vehicle' ) |\
         (df['BODY_TYPE_CODE'] =='Low Speed Vehicle' )|(df['BODY_TYPE_CODE'] =='Snowmobile' )] = "Recreational"
body_df[(df['BODY_TYPE_CODE'] == 'Motorcycle') | (df['BODY_TYPE_CODE'] =='Moped' )] = "Motorcycle"
body_df[(df['BODY_TYPE_CODE'] == 'Truck Tractor') | (df['BODY_TYPE_CODE'] =='Farm Vehicle' )] = "Farm"

df['BODY_TYPE_CODE'] = body_df
df['BODY_TYPE_CODE'].unique()
# Out:
# array(['Passenger Car', 'Truck', 'Bus', 'Recreational',
#        'Special/Non Emergency', 'Special/Emergency', 'Farm', 'Motorcycle'], dtype=object)

# %% [markdown]
# # SURF_COND_CODE :
#  ['Wet' 'Dry' 'Ice' 'Snow' 'Oil' 'Slush' 'Mud, Dirt, Gravel'
#  'Water (standing/moving)' 'Sand']

# %%
surf_df = df['SURF_COND_CODE'].copy()

surf_df[(df['SURF_COND_CODE'] == 'Ice') | (df['SURF_COND_CODE'] =='Slush') |\
         (df['SURF_COND_CODE'] =='Snow')] = "Winter"
surf_df[(df['SURF_COND_CODE'] == 'Water (standing/moving)')] = "Wet"
surf_df[(df['SURF_COND_CODE'] == 'Oil') | (df['SURF_COND_CODE'] =='Mud, Dirt, Gravel') |\
         (df['SURF_COND_CODE'] =='Sand')] = "Others"
df['SURF_COND_CODE'] = surf_df
df['SURF_COND_CODE'].unique()
# Out:
# array(['Wet', 'Dry', 'Winter', 'Others'], dtype=object)

# %% [markdown]
# # WEATHER_CODE :
#  ['Raining' 'Clear' 'Wintry Mix' 'Snow' 'Sleet' 'Cloudy' 'Severe Winds'
#  'Blowing Snow' 'Foggy' 'Blowing Sand, Soil, Dirt']

# %%
weather_df = df['WEATHER_CODE'].copy()

weather_df[(df['WEATHER_CODE'] == 'Sleet')|(df['WEATHER_CODE'] == 'Blowing Snow')|(df['WEATHER_CODE'] == 'Wintry Mix')] = "Snow"
weather_df[(df['WEATHER_CODE'] == 'Cloudy')] = "Clear"
df['WEATHER_CODE'] = weather_df
df['WEATHER_CODE'].unique()
# Out:
# array(['Raining', 'Clear', 'Snow', 'Severe Winds', 'Foggy',
#        'Blowing Sand, Soil, Dirt'], dtype=object)

# %% [markdown]
# ### convert hour

# %%
from datetime import datetime

convert_hour = lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S').hour
df['TIME'] = df["TIME"].apply(convert_hour)

# %% [markdown]
# ### classify time period

# %%
time_period = df["TIME"].copy()

time_period[(0<=df['TIME']) & (df['TIME']<6)] = 'DAWN'
time_period[(6<=df['TIME']) & (df['TIME']<12)] = 'MORNING'
time_period[(12<=df['TIME']) & (df['TIME']<18)] = 'AFTERNOON'
time_period[(18<=df['TIME'])] = 'EVENING'
df['TIME_PERIOD'] = time_period
df.tail()
# Out:
#          REPORT_NO CDL_FLAG CONDITION_CODE EQUIP_PROB_CODE FAULT_FLAG  \
# 29588  MCP2526000L        N         Asleep       No Misuse          Y
# 29589   AC2051000K        N    Alchol/Drug       No Misuse          Y
# 29590   ADI5630003        N    Alchol/Drug       No Misuse          Y
# 29591   HM0146000D        N    Alchol/Drug       No Misuse          Y
# 29592  MCP1519000S        N    Alchol/Drug          Misuse          Y
#
#       INJ_SEVER_CODE                             PERSON_ID PERSON_TYPE  \
# 29588              8  e0715157-51da-4266-bfeb-9dbb80117fba           D
# 29589              1  15f07506-e12b-4b2a-aa31-44635150d1c2           D
# 29590              1  63529935-542d-4c69-af1f-1b3e49894090           D
# 29591              1  400dc255-6c26-4e47-9f75-920439556f0b           D
# 29592              8  6dbbc5b4-3922-4726-ae9f-d4140e986ea4           D
#
#       SAF_EQUIP_CODE SEX_CODE                            VEHICLE_ID  \
# 29588           Belt        M  40840738-5b3e-4c2f-b56c-430b6e2875a6
# 29589           Belt        M  fbbdb263-5979-4a02-bf49-88a840fd8e2e
# 29590           Belt        M  acfa1fcd-e286-4e64-ba2b-36894375ccc8
# 29591           Belt        M  1075765b-229c-478a-8d42-b4d41ec35309
# 29592           Belt        M  cec5b365-1040-4898-8943-fa9259c1189c
#
#            COLLISION_TYPE_CODE C_M_ZONE_FLAG     JUNCTION_CODE  \
# 29588          Single Vehicle              N      Intersection
# 29589          Single Vehicle              N  Non Intersection
# 29590  Same Direction Rear End             N  Non Intersection
# 29591          Single Vehicle              N  Non Intersection
# 29592          Single Vehicle              N  Non Intersection
#
#                LANE_CODE      LIGHT_CODE            RD_COND_CODE  \
# 29588  Acceleration Lane        Daylight              No Defects
# 29589    Right Turn Lane  Dark Lights On              No Defects
# 29590  Acceleration Lane            Dusk              No Defects
# 29591    Right Turn Lane  Dark No Lights  Loose Surface Material
# 29592    Right Turn Lane  Dark Lights On              No Defects
#
#                                              RD_DIV_CODE SURF_COND_CODE  \
# 29588                               Two-way, Not Divided            Dry
# 29589  Two-way, Divided, Unprotected (painted >4 feet...            Dry
# 29590          Two-way, Divided, Positive Median Barrier            Dry
# 29591                               Two-way, Not Divided         Others
# 29592          Two-way, Divided, Positive Median Barrier            Dry
#
#       WEATHER_CODE AREA_DAMAGED_CODE_MAIN BODY_TYPE_CODE  DAMAGE_CODE  \
# 29588        Clear                  Front  Passenger Car    Disabling
# 29589        Clear                  Front  Passenger Car    Disabling
# 29590        Clear                  Front  Passenger Car  Superficial
# 29591        Clear                  Front  Passenger Car    Disabling
# 29592        Clear                  Front  Passenger Car    Disabling
#
#       HIT_AND_RUN_FLAG          MOVEMENT_CODE  TIME   AGE TIME_PERIOD
# 29588                N  Moving Constant Speed    15  28.0   AFTERNOON
# 29589                N  Moving Constant Speed    22  42.0     EVENING
# 29590                N    Slowing or Stopping    18  51.0     EVENING
# 29591                Y  Moving Constant Speed    22  26.0     EVENING
# 29592                N  Moving Constant Speed     2  45.0        DAWN

# %%
counts_per_time_period = df[['TIME_PERIOD']].groupby(df['TIME_PERIOD']).count()
fig3 = counts_per_time_period.plot.bar()
fig3.set_ylabel("Count")
plt.show()

# %%
df.tail()
# Out:
#          REPORT_NO CDL_FLAG CONDITION_CODE EQUIP_PROB_CODE FAULT_FLAG  \
# 29588  MCP2526000L        N         Asleep       No Misuse          Y
# 29589   AC2051000K        N    Alchol/Drug       No Misuse          Y
# 29590   ADI5630003        N    Alchol/Drug       No Misuse          Y
# 29591   HM0146000D        N    Alchol/Drug       No Misuse          Y
# 29592  MCP1519000S        N    Alchol/Drug          Misuse          Y
#
#       INJ_SEVER_CODE                             PERSON_ID PERSON_TYPE  \
# 29588              8  e0715157-51da-4266-bfeb-9dbb80117fba           D
# 29589              1  15f07506-e12b-4b2a-aa31-44635150d1c2           D
# 29590              1  63529935-542d-4c69-af1f-1b3e49894090           D
# 29591              1  400dc255-6c26-4e47-9f75-920439556f0b           D
# 29592              8  6dbbc5b4-3922-4726-ae9f-d4140e986ea4           D
#
#       SAF_EQUIP_CODE SEX_CODE                            VEHICLE_ID  \
# 29588           Belt        M  40840738-5b3e-4c2f-b56c-430b6e2875a6
# 29589           Belt        M  fbbdb263-5979-4a02-bf49-88a840fd8e2e
# 29590           Belt        M  acfa1fcd-e286-4e64-ba2b-36894375ccc8
# 29591           Belt        M  1075765b-229c-478a-8d42-b4d41ec35309
# 29592           Belt        M  cec5b365-1040-4898-8943-fa9259c1189c
#
#            COLLISION_TYPE_CODE C_M_ZONE_FLAG     JUNCTION_CODE  \
# 29588          Single Vehicle              N      Intersection
# 29589          Single Vehicle              N  Non Intersection
# 29590  Same Direction Rear End             N  Non Intersection
# 29591          Single Vehicle              N  Non Intersection
# 29592          Single Vehicle              N  Non Intersection
#
#                LANE_CODE      LIGHT_CODE            RD_COND_CODE  \
# 29588  Acceleration Lane        Daylight              No Defects
# 29589    Right Turn Lane  Dark Lights On              No Defects
# 29590  Acceleration Lane            Dusk              No Defects
# 29591    Right Turn Lane  Dark No Lights  Loose Surface Material
# 29592    Right Turn Lane  Dark Lights On              No Defects
#
#                                              RD_DIV_CODE SURF_COND_CODE  \
# 29588                               Two-way, Not Divided            Dry
# 29589  Two-way, Divided, Unprotected (painted >4 feet...            Dry
# 29590          Two-way, Divided, Positive Median Barrier            Dry
# 29591                               Two-way, Not Divided         Others
# 29592          Two-way, Divided, Positive Median Barrier            Dry
#
#       WEATHER_CODE AREA_DAMAGED_CODE_MAIN BODY_TYPE_CODE  DAMAGE_CODE  \
# 29588        Clear                  Front  Passenger Car    Disabling
# 29589        Clear                  Front  Passenger Car    Disabling
# 29590        Clear                  Front  Passenger Car  Superficial
# 29591        Clear                  Front  Passenger Car    Disabling
# 29592        Clear                  Front  Passenger Car    Disabling
#
#       HIT_AND_RUN_FLAG          MOVEMENT_CODE  TIME   AGE TIME_PERIOD
# 29588                N  Moving Constant Speed    15  28.0   AFTERNOON
# 29589                N  Moving Constant Speed    22  42.0     EVENING
# 29590                N    Slowing or Stopping    18  51.0     EVENING
# 29591                Y  Moving Constant Speed    22  26.0     EVENING
# 29592                N  Moving Constant Speed     2  45.0        DAWN

# %% [markdown]
# # drop cols

# %%
df.columns
# Out:
# Index(['REPORT_NO', 'CDL_FLAG', 'CONDITION_CODE', 'EQUIP_PROB_CODE',
#        'FAULT_FLAG', 'INJ_SEVER_CODE', 'PERSON_ID', 'PERSON_TYPE',
#        'SAF_EQUIP_CODE', 'SEX_CODE', 'VEHICLE_ID', 'COLLISION_TYPE_CODE',
#        'C_M_ZONE_FLAG', 'JUNCTION_CODE', 'LANE_CODE', 'LIGHT_CODE',
#        'RD_COND_CODE', 'RD_DIV_CODE', 'SURF_COND_CODE', 'WEATHER_CODE',
#        'AREA_DAMAGED_CODE_MAIN', 'BODY_TYPE_CODE', 'DAMAGE_CODE',
#        'HIT_AND_RUN_FLAG', 'MOVEMENT_CODE', 'TIME', 'AGE', 'TIME_PERIOD'],
#       dtype='object')

# %%
want_to_drop_cols = ['INJ_SEVER_CODE','DAMAGE_CODE', 'REPORT_NO', 'CDL_FLAG','PERSON_ID', 'PERSON_TYPE', 'FAULT_FLAG','SEX_CODE', 'VEHICLE_ID','C_M_ZONE_FLAG','HIT_AND_RUN_FLAG', 'TIME']
df = df.drop(want_to_drop_cols, axis = 1)
df.columns
# Out:
# Index(['CONDITION_CODE', 'EQUIP_PROB_CODE', 'SAF_EQUIP_CODE',
#        'COLLISION_TYPE_CODE', 'JUNCTION_CODE', 'LANE_CODE', 'LIGHT_CODE',
#        'RD_COND_CODE', 'RD_DIV_CODE', 'SURF_COND_CODE', 'WEATHER_CODE',
#        'AREA_DAMAGED_CODE_MAIN', 'BODY_TYPE_CODE', 'MOVEMENT_CODE', 'AGE',
#        'TIME_PERIOD'],
#       dtype='object')

# %%
#appropriate_df = df.drop(want_to_drop_cols, axis = 1)

appropriate_df = df.copy()
appropriate_df.tail()
# Out:
#       CONDITION_CODE EQUIP_PROB_CODE SAF_EQUIP_CODE      COLLISION_TYPE_CODE  \
# 29588         Asleep       No Misuse           Belt          Single Vehicle
# 29589    Alchol/Drug       No Misuse           Belt          Single Vehicle
# 29590    Alchol/Drug       No Misuse           Belt  Same Direction Rear End
# 29591    Alchol/Drug       No Misuse           Belt          Single Vehicle
# 29592    Alchol/Drug          Misuse           Belt          Single Vehicle
#
#           JUNCTION_CODE          LANE_CODE      LIGHT_CODE  \
# 29588      Intersection  Acceleration Lane        Daylight
# 29589  Non Intersection    Right Turn Lane  Dark Lights On
# 29590  Non Intersection  Acceleration Lane            Dusk
# 29591  Non Intersection    Right Turn Lane  Dark No Lights
# 29592  Non Intersection    Right Turn Lane  Dark Lights On
#
#                  RD_COND_CODE  \
# 29588              No Defects
# 29589              No Defects
# 29590              No Defects
# 29591  Loose Surface Material
# 29592              No Defects
#
#                                              RD_DIV_CODE SURF_COND_CODE  \
# 29588                               Two-way, Not Divided            Dry
# 29589  Two-way, Divided, Unprotected (painted >4 feet...            Dry
# 29590          Two-way, Divided, Positive Median Barrier            Dry
# 29591                               Two-way, Not Divided         Others
# 29592          Two-way, Divided, Positive Median Barrier            Dry
#
#       WEATHER_CODE AREA_DAMAGED_CODE_MAIN BODY_TYPE_CODE  \
# 29588        Clear                  Front  Passenger Car
# 29589        Clear                  Front  Passenger Car
# 29590        Clear                  Front  Passenger Car
# 29591        Clear                  Front  Passenger Car
# 29592        Clear                  Front  Passenger Car
#
#                MOVEMENT_CODE   AGE TIME_PERIOD
# 29588  Moving Constant Speed  28.0   AFTERNOON
# 29589  Moving Constant Speed  42.0     EVENING
# 29590    Slowing or Stopping  51.0     EVENING
# 29591  Moving Constant Speed  26.0     EVENING
# 29592  Moving Constant Speed  45.0        DAWN

# %%
want_to_dummify_cols = []
for col in list(appropriate_df.columns):
    if (not col == "AGE") and (not col == "INJ_SEVER_CODE"):
        want_to_dummify_cols.append(col)

dummified_df = pd.get_dummies(appropriate_df, columns = want_to_dummify_cols)
dummified_df.tail()
# Out:
#         AGE  CONDITION_CODE_Alchol/Drug  CONDITION_CODE_Apparently Normal  \
# 29588  28.0                           0                                 0
# 29589  42.0                           1                                 0
# 29590  51.0                           1                                 0
# 29591  26.0                           1                                 0
# 29592  45.0                           1                                 0
#
#        CONDITION_CODE_Asleep  \
# 29588                      1
# 29589                      0
# 29590                      0
# 29591                      0
# 29592                      0
#
#        CONDITION_CODE_Emotional Depressed Angry Disturbed  CONDITION_CODE_Ill  \
# 29588                                                  0                    0
# 29589                                                  0                    0
# 29590                                                  0                    0
# 29591                                                  0                    0
# 29592                                                  0                    0
#
#        CONDITION_CODE_Other Handicaps  EQUIP_PROB_CODE_Misuse  \
# 29588                               0                       0
# 29589                               0                       0
# 29590                               0                       0
# 29591                               0                       0
# 29592                               0                       1
#
#        EQUIP_PROB_CODE_No Misuse  SAF_EQUIP_CODE_Belt  \
# 29588                          1                    1
# 29589                          1                    1
# 29590                          1                    1
# 29591                          1                    1
# 29592                          0                    1
#
#        SAF_EQUIP_CODE_Child System  SAF_EQUIP_CODE_Lighting  \
# 29588                            0                        0
# 29589                            0                        0
# 29590                            0                        0
# 29591                            0                        0
# 29592                            0                        0
#
#        SAF_EQUIP_CODE_MC/Bike  SAF_EQUIP_CODE_None    \
# 29588                       0                      0
# 29589                       0                      0
# 29590                       0                      0
# 29591                       0                      0
# 29592                       0                      0
#
#        COLLISION_TYPE_CODE_Angle Meets  COLLISION_TYPE_CODE_Head On  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        COLLISION_TYPE_CODE_Opposite Direction  \
# 29588                                       0
# 29589                                       0
# 29590                                       0
# 29591                                       0
# 29592                                       0
#
#        COLLISION_TYPE_CODE_Same Direction Rear End  \
# 29588                                            0
# 29589                                            0
# 29590                                            1
# 29591                                            0
# 29592                                            0
#
#        COLLISION_TYPE_CODE_Same Direction Sideswipe  \
# 29588                                             0
# 29589                                             0
# 29590                                             0
# 29591                                             0
# 29592                                             0
#
#        COLLISION_TYPE_CODE_Same Direction/Turn  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Same Movement Angle  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Single Vehicle   JUNCTION_CODE_Alley  \
# 29588                                    1                    0
# 29589                                    1                    0
# 29590                                    0                    0
# 29591                                    1                    0
# 29592                                    1                    0
#
#        JUNCTION_CODE_Commercial Driveway  JUNCTION_CODE_Crossover Related  \
# 29588                                  0                                0
# 29589                                  0                                0
# 29590                                  0                                0
# 29591                                  0                                0
# 29592                                  0                                0
#
#        JUNCTION_CODE_Interchange Related  JUNCTION_CODE_Intersection  \
# 29588                                  0                           1
# 29589                                  0                           0
# 29590                                  0                           0
# 29591                                  0                           0
# 29592                                  0                           0
#
#        JUNCTION_CODE_Intersection Related  JUNCTION_CODE_Non Intersection  \
# 29588                                   0                               0
# 29589                                   0                               1
# 29590                                   0                               1
# 29591                                   0                               1
# 29592                                   0                               1
#
#        JUNCTION_CODE_Railway Grade Crossing  \
# 29588                                     0
# 29589                                     0
# 29590                                     0
# 29591                                     0
# 29592                                     0
#
#        JUNCTION_CODE_Residential Driveway  LANE_CODE_Acceleration Lane  \
# 29588                                   0                            1
# 29589                                   0                            0
# 29590                                   0                            1
# 29591                                   0                            0
# 29592                                   0                            0
#
#        LANE_CODE_Crossover Area  LANE_CODE_Deceleration Lane  \
# 29588                         0                            0
# 29589                         0                            0
# 29590                         0                            0
# 29591                         0                            0
# 29592                         0                            0
#
#        LANE_CODE_Left Turn Lane  LANE_CODE_Right Turn Lane  \
# 29588                         0                          0
# 29589                         0                          1
# 29590                         0                          0
# 29591                         0                          1
# 29592                         0                          1
#
#        LANE_CODE_Separator  LANE_CODE_Shoulder Area  \
# 29588                    0                        0
# 29589                    0                        0
# 29590                    0                        0
# 29591                    0                        0
# 29592                    0                        0
#
#        LIGHT_CODE_Dark - Unknown Lighting  LIGHT_CODE_Dark Lights On  \
# 29588                                   0                          0
# 29589                                   0                          1
# 29590                                   0                          0
# 29591                                   0                          0
# 29592                                   0                          1
#
#        LIGHT_CODE_Dark No Lights  LIGHT_CODE_Dawn  LIGHT_CODE_Daylight  \
# 29588                          0                0                    1
# 29589                          0                0                    0
# 29590                          0                0                    0
# 29591                          1                0                    0
# 29592                          0                0                    0
#
#        LIGHT_CODE_Dusk  RD_COND_CODE_Foreign Material  \
# 29588                0                              0
# 29589                0                              0
# 29590                1                              0
# 29591                0                              0
# 29592                0                              0
#
#        RD_COND_CODE_Holes, Ruts, Etc.  RD_COND_CODE_Loose Surface Material  \
# 29588                               0                                    0
# 29589                               0                                    0
# 29590                               0                                    0
# 29591                               0                                    1
# 29592                               0                                    0
#
#        RD_COND_CODE_No Defects  RD_COND_CODE_Obstruction Not Lighted  \
# 29588                        1                                     0
# 29589                        1                                     0
# 29590                        1                                     0
# 29591                        0                                     0
# 29592                        1                                     0
#
#        RD_COND_CODE_Obstruction Not Signaled  RD_COND_CODE_Shoulder Defect  \
# 29588                                      0                             0
# 29589                                      0                             0
# 29590                                      0                             0
# 29591                                      0                             0
# 29592                                      0                             0
#
#        RD_COND_CODE_View Obstructed  RD_DIV_CODE_One-way Trafficway  \
# 29588                             0                               0
# 29589                             0                               0
# 29590                             0                               0
# 29591                             0                               0
# 29592                             0                               0
#
#        RD_DIV_CODE_Two-way, Divided, Positive Median Barrier  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  1
# 29591                                                  0
# 29592                                                  1
#
#        RD_DIV_CODE_Two-way, Divided, Unprotected (painted >4 feet) Median  \
# 29588                                                  0
# 29589                                                  1
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        RD_DIV_CODE_Two-way, Not Divided  \
# 29588                                 1
# 29589                                 0
# 29590                                 0
# 29591                                 1
# 29592                                 0
#
#        RD_DIV_CODE_Two-way, Not Divided with a Continuous Left Turn Lane  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        SURF_COND_CODE_Dry  SURF_COND_CODE_Others  SURF_COND_CODE_Wet  \
# 29588                   1                      0                   0
# 29589                   1                      0                   0
# 29590                   1                      0                   0
# 29591                   0                      1                   0
# 29592                   1                      0                   0
#
#        SURF_COND_CODE_Winter  WEATHER_CODE_Blowing Sand, Soil, Dirt  \
# 29588                      0                                      0
# 29589                      0                                      0
# 29590                      0                                      0
# 29591                      0                                      0
# 29592                      0                                      0
#
#        WEATHER_CODE_Clear  WEATHER_CODE_Foggy  WEATHER_CODE_Raining  \
# 29588                   1                   0                     0
# 29589                   1                   0                     0
# 29590                   1                   0                     0
# 29591                   1                   0                     0
# 29592                   1                   0                     0
#
#        WEATHER_CODE_Severe Winds  WEATHER_CODE_Snow  \
# 29588                          0                  0
# 29589                          0                  0
# 29590                          0                  0
# 29591                          0                  0
# 29592                          0                  0
#
#        AREA_DAMAGED_CODE_MAIN_Front  AREA_DAMAGED_CODE_MAIN_Rear  \
# 29588                             1                            0
# 29589                             1                            0
# 29590                             1                            0
# 29591                             1                            0
# 29592                             1                            0
#
#        AREA_DAMAGED_CODE_MAIN_Side  BODY_TYPE_CODE_Bus  BODY_TYPE_CODE_Farm  \
# 29588                            0                   0                    0
# 29589                            0                   0                    0
# 29590                            0                   0                    0
# 29591                            0                   0                    0
# 29592                            0                   0                    0
#
#        BODY_TYPE_CODE_Motorcycle  BODY_TYPE_CODE_Passenger Car  \
# 29588                          0                             1
# 29589                          0                             1
# 29590                          0                             1
# 29591                          0                             1
# 29592                          0                             1
#
#        BODY_TYPE_CODE_Recreational  BODY_TYPE_CODE_Special/Emergency  \
# 29588                            0                                 0
# 29589                            0                                 0
# 29590                            0                                 0
# 29591                            0                                 0
# 29592                            0                                 0
#
#        BODY_TYPE_CODE_Special/Non Emergency  BODY_TYPE_CODE_Truck  \
# 29588                                     0                     0
# 29589                                     0                     0
# 29590                                     0                     0
# 29591                                     0                     0
# 29592                                     0                     0
#
#        MOVEMENT_CODE_Accelerating  MOVEMENT_CODE_Backing  \
# 29588                           0                      0
# 29589                           0                      0
# 29590                           0                      0
# 29591                           0                      0
# 29592                           0                      0
#
#        MOVEMENT_CODE_Changing Lanes  MOVEMENT_CODE_Driverless Moving Vehicle  \
# 29588                             0                                        0
# 29589                             0                                        0
# 29590                             0                                        0
# 29591                             0                                        0
# 29592                             0                                        0
#
#        MOVEMENT_CODE_Entering Traffic Lane  \
# 29588                                    0
# 29589                                    0
# 29590                                    0
# 29591                                    0
# 29592                                    0
#
#        MOVEMENT_CODE_Leaving Traffic Lane  MOVEMENT_CODE_Making Left Turn  \
# 29588                                   0                               0
# 29589                                   0                               0
# 29590                                   0                               0
# 29591                                   0                               0
# 29592                                   0                               0
#
#        MOVEMENT_CODE_Making Right Turn  MOVEMENT_CODE_Making U Turn  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        MOVEMENT_CODE_Moving Constant Speed  MOVEMENT_CODE_Negotiating a Curve  \
# 29588                                    1                                  0
# 29589                                    1                                  0
# 29590                                    0                                  0
# 29591                                    1                                  0
# 29592                                    1                                  0
#
#        MOVEMENT_CODE_Parked    MOVEMENT_CODE_Parking    MOVEMENT_CODE_Passing  \
# 29588                       0                        0                      0
# 29589                       0                        0                      0
# 29590                       0                        0                      0
# 29591                       0                        0                      0
# 29592                       0                        0                      0
#
#        MOVEMENT_CODE_Right Turn on Red  MOVEMENT_CODE_Skidding  \
# 29588                                0                       0
# 29589                                0                       0
# 29590                                0                       0
# 29591                                0                       0
# 29592                                0                       0
#
#        MOVEMENT_CODE_Slowing or Stopping  MOVEMENT_CODE_Starting From Lane  \
# 29588                                  0                                 0
# 29589                                  0                                 0
# 29590                                  1                                 0
# 29591                                  0                                 0
# 29592                                  0                                 0
#
#        MOVEMENT_CODE_Starting From Parked  \
# 29588                                   0
# 29589                                   0
# 29590                                   0
# 29591                                   0
# 29592                                   0
#
#        MOVEMENT_CODE_Stopped in Traffic Lane  TIME_PERIOD_AFTERNOON  \
# 29588                                      0                      1
# 29589                                      0                      0
# 29590                                      0                      0
# 29591                                      0                      0
# 29592                                      0                      0
#
#        TIME_PERIOD_DAWN  TIME_PERIOD_EVENING  TIME_PERIOD_MORNING
# 29588                 0                    0                    0
# 29589                 0                    1                    0
# 29590                 0                    1                    0
# 29591                 0                    1                    0
# 29592                 1                    0                    0

# %%
#want_to_scale_cols = ["AGE", "INJ_SEVER_CODE"]
scaled_df = dummified_df.copy()
scaled_df["AGE"] = (scaled_df["AGE"].mean() - scaled_df["AGE"])/scaled_df["AGE"].std()
#scaled_df["INJ_SEVER_CODE"] = (scaled_df["INJ_SEVER_CODE"].mean() - scaled_df["INJ_SEVER_CODE"])/scaled_df["INJ_SEVER_CODE"].std()

# %%
scaled_df.tail()
# Out:
#             AGE  CONDITION_CODE_Alchol/Drug  CONDITION_CODE_Apparently Normal  \
# 29588  0.771133                           0                                 0
# 29589 -0.109788                           1                                 0
# 29590 -0.676095                           1                                 0
# 29591  0.896979                           1                                 0
# 29592 -0.298557                           1                                 0
#
#        CONDITION_CODE_Asleep  \
# 29588                      1
# 29589                      0
# 29590                      0
# 29591                      0
# 29592                      0
#
#        CONDITION_CODE_Emotional Depressed Angry Disturbed  CONDITION_CODE_Ill  \
# 29588                                                  0                    0
# 29589                                                  0                    0
# 29590                                                  0                    0
# 29591                                                  0                    0
# 29592                                                  0                    0
#
#        CONDITION_CODE_Other Handicaps  EQUIP_PROB_CODE_Misuse  \
# 29588                               0                       0
# 29589                               0                       0
# 29590                               0                       0
# 29591                               0                       0
# 29592                               0                       1
#
#        EQUIP_PROB_CODE_No Misuse  SAF_EQUIP_CODE_Belt  \
# 29588                          1                    1
# 29589                          1                    1
# 29590                          1                    1
# 29591                          1                    1
# 29592                          0                    1
#
#        SAF_EQUIP_CODE_Child System  SAF_EQUIP_CODE_Lighting  \
# 29588                            0                        0
# 29589                            0                        0
# 29590                            0                        0
# 29591                            0                        0
# 29592                            0                        0
#
#        SAF_EQUIP_CODE_MC/Bike  SAF_EQUIP_CODE_None    \
# 29588                       0                      0
# 29589                       0                      0
# 29590                       0                      0
# 29591                       0                      0
# 29592                       0                      0
#
#        COLLISION_TYPE_CODE_Angle Meets  COLLISION_TYPE_CODE_Head On  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        COLLISION_TYPE_CODE_Opposite Direction  \
# 29588                                       0
# 29589                                       0
# 29590                                       0
# 29591                                       0
# 29592                                       0
#
#        COLLISION_TYPE_CODE_Same Direction Rear End  \
# 29588                                            0
# 29589                                            0
# 29590                                            1
# 29591                                            0
# 29592                                            0
#
#        COLLISION_TYPE_CODE_Same Direction Sideswipe  \
# 29588                                             0
# 29589                                             0
# 29590                                             0
# 29591                                             0
# 29592                                             0
#
#        COLLISION_TYPE_CODE_Same Direction/Turn  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Same Movement Angle  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Single Vehicle   JUNCTION_CODE_Alley  \
# 29588                                    1                    0
# 29589                                    1                    0
# 29590                                    0                    0
# 29591                                    1                    0
# 29592                                    1                    0
#
#        JUNCTION_CODE_Commercial Driveway  JUNCTION_CODE_Crossover Related  \
# 29588                                  0                                0
# 29589                                  0                                0
# 29590                                  0                                0
# 29591                                  0                                0
# 29592                                  0                                0
#
#        JUNCTION_CODE_Interchange Related  JUNCTION_CODE_Intersection  \
# 29588                                  0                           1
# 29589                                  0                           0
# 29590                                  0                           0
# 29591                                  0                           0
# 29592                                  0                           0
#
#        JUNCTION_CODE_Intersection Related  JUNCTION_CODE_Non Intersection  \
# 29588                                   0                               0
# 29589                                   0                               1
# 29590                                   0                               1
# 29591                                   0                               1
# 29592                                   0                               1
#
#        JUNCTION_CODE_Railway Grade Crossing  \
# 29588                                     0
# 29589                                     0
# 29590                                     0
# 29591                                     0
# 29592                                     0
#
#        JUNCTION_CODE_Residential Driveway  LANE_CODE_Acceleration Lane  \
# 29588                                   0                            1
# 29589                                   0                            0
# 29590                                   0                            1
# 29591                                   0                            0
# 29592                                   0                            0
#
#        LANE_CODE_Crossover Area  LANE_CODE_Deceleration Lane  \
# 29588                         0                            0
# 29589                         0                            0
# 29590                         0                            0
# 29591                         0                            0
# 29592                         0                            0
#
#        LANE_CODE_Left Turn Lane  LANE_CODE_Right Turn Lane  \
# 29588                         0                          0
# 29589                         0                          1
# 29590                         0                          0
# 29591                         0                          1
# 29592                         0                          1
#
#        LANE_CODE_Separator  LANE_CODE_Shoulder Area  \
# 29588                    0                        0
# 29589                    0                        0
# 29590                    0                        0
# 29591                    0                        0
# 29592                    0                        0
#
#        LIGHT_CODE_Dark - Unknown Lighting  LIGHT_CODE_Dark Lights On  \
# 29588                                   0                          0
# 29589                                   0                          1
# 29590                                   0                          0
# 29591                                   0                          0
# 29592                                   0                          1
#
#        LIGHT_CODE_Dark No Lights  LIGHT_CODE_Dawn  LIGHT_CODE_Daylight  \
# 29588                          0                0                    1
# 29589                          0                0                    0
# 29590                          0                0                    0
# 29591                          1                0                    0
# 29592                          0                0                    0
#
#        LIGHT_CODE_Dusk  RD_COND_CODE_Foreign Material  \
# 29588                0                              0
# 29589                0                              0
# 29590                1                              0
# 29591                0                              0
# 29592                0                              0
#
#        RD_COND_CODE_Holes, Ruts, Etc.  RD_COND_CODE_Loose Surface Material  \
# 29588                               0                                    0
# 29589                               0                                    0
# 29590                               0                                    0
# 29591                               0                                    1
# 29592                               0                                    0
#
#        RD_COND_CODE_No Defects  RD_COND_CODE_Obstruction Not Lighted  \
# 29588                        1                                     0
# 29589                        1                                     0
# 29590                        1                                     0
# 29591                        0                                     0
# 29592                        1                                     0
#
#        RD_COND_CODE_Obstruction Not Signaled  RD_COND_CODE_Shoulder Defect  \
# 29588                                      0                             0
# 29589                                      0                             0
# 29590                                      0                             0
# 29591                                      0                             0
# 29592                                      0                             0
#
#        RD_COND_CODE_View Obstructed  RD_DIV_CODE_One-way Trafficway  \
# 29588                             0                               0
# 29589                             0                               0
# 29590                             0                               0
# 29591                             0                               0
# 29592                             0                               0
#
#        RD_DIV_CODE_Two-way, Divided, Positive Median Barrier  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  1
# 29591                                                  0
# 29592                                                  1
#
#        RD_DIV_CODE_Two-way, Divided, Unprotected (painted >4 feet) Median  \
# 29588                                                  0
# 29589                                                  1
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        RD_DIV_CODE_Two-way, Not Divided  \
# 29588                                 1
# 29589                                 0
# 29590                                 0
# 29591                                 1
# 29592                                 0
#
#        RD_DIV_CODE_Two-way, Not Divided with a Continuous Left Turn Lane  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        SURF_COND_CODE_Dry  SURF_COND_CODE_Others  SURF_COND_CODE_Wet  \
# 29588                   1                      0                   0
# 29589                   1                      0                   0
# 29590                   1                      0                   0
# 29591                   0                      1                   0
# 29592                   1                      0                   0
#
#        SURF_COND_CODE_Winter  WEATHER_CODE_Blowing Sand, Soil, Dirt  \
# 29588                      0                                      0
# 29589                      0                                      0
# 29590                      0                                      0
# 29591                      0                                      0
# 29592                      0                                      0
#
#        WEATHER_CODE_Clear  WEATHER_CODE_Foggy  WEATHER_CODE_Raining  \
# 29588                   1                   0                     0
# 29589                   1                   0                     0
# 29590                   1                   0                     0
# 29591                   1                   0                     0
# 29592                   1                   0                     0
#
#        WEATHER_CODE_Severe Winds  WEATHER_CODE_Snow  \
# 29588                          0                  0
# 29589                          0                  0
# 29590                          0                  0
# 29591                          0                  0
# 29592                          0                  0
#
#        AREA_DAMAGED_CODE_MAIN_Front  AREA_DAMAGED_CODE_MAIN_Rear  \
# 29588                             1                            0
# 29589                             1                            0
# 29590                             1                            0
# 29591                             1                            0
# 29592                             1                            0
#
#        AREA_DAMAGED_CODE_MAIN_Side  BODY_TYPE_CODE_Bus  BODY_TYPE_CODE_Farm  \
# 29588                            0                   0                    0
# 29589                            0                   0                    0
# 29590                            0                   0                    0
# 29591                            0                   0                    0
# 29592                            0                   0                    0
#
#        BODY_TYPE_CODE_Motorcycle  BODY_TYPE_CODE_Passenger Car  \
# 29588                          0                             1
# 29589                          0                             1
# 29590                          0                             1
# 29591                          0                             1
# 29592                          0                             1
#
#        BODY_TYPE_CODE_Recreational  BODY_TYPE_CODE_Special/Emergency  \
# 29588                            0                                 0
# 29589                            0                                 0
# 29590                            0                                 0
# 29591                            0                                 0
# 29592                            0                                 0
#
#        BODY_TYPE_CODE_Special/Non Emergency  BODY_TYPE_CODE_Truck  \
# 29588                                     0                     0
# 29589                                     0                     0
# 29590                                     0                     0
# 29591                                     0                     0
# 29592                                     0                     0
#
#        MOVEMENT_CODE_Accelerating  MOVEMENT_CODE_Backing  \
# 29588                           0                      0
# 29589                           0                      0
# 29590                           0                      0
# 29591                           0                      0
# 29592                           0                      0
#
#        MOVEMENT_CODE_Changing Lanes  MOVEMENT_CODE_Driverless Moving Vehicle  \
# 29588                             0                                        0
# 29589                             0                                        0
# 29590                             0                                        0
# 29591                             0                                        0
# 29592                             0                                        0
#
#        MOVEMENT_CODE_Entering Traffic Lane  \
# 29588                                    0
# 29589                                    0
# 29590                                    0
# 29591                                    0
# 29592                                    0
#
#        MOVEMENT_CODE_Leaving Traffic Lane  MOVEMENT_CODE_Making Left Turn  \
# 29588                                   0                               0
# 29589                                   0                               0
# 29590                                   0                               0
# 29591                                   0                               0
# 29592                                   0                               0
#
#        MOVEMENT_CODE_Making Right Turn  MOVEMENT_CODE_Making U Turn  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        MOVEMENT_CODE_Moving Constant Speed  MOVEMENT_CODE_Negotiating a Curve  \
# 29588                                    1                                  0
# 29589                                    1                                  0
# 29590                                    0                                  0
# 29591                                    1                                  0
# 29592                                    1                                  0
#
#        MOVEMENT_CODE_Parked    MOVEMENT_CODE_Parking    MOVEMENT_CODE_Passing  \
# 29588                       0                        0                      0
# 29589                       0                        0                      0
# 29590                       0                        0                      0
# 29591                       0                        0                      0
# 29592                       0                        0                      0
#
#        MOVEMENT_CODE_Right Turn on Red  MOVEMENT_CODE_Skidding  \
# 29588                                0                       0
# 29589                                0                       0
# 29590                                0                       0
# 29591                                0                       0
# 29592                                0                       0
#
#        MOVEMENT_CODE_Slowing or Stopping  MOVEMENT_CODE_Starting From Lane  \
# 29588                                  0                                 0
# 29589                                  0                                 0
# 29590                                  1                                 0
# 29591                                  0                                 0
# 29592                                  0                                 0
#
#        MOVEMENT_CODE_Starting From Parked  \
# 29588                                   0
# 29589                                   0
# 29590                                   0
# 29591                                   0
# 29592                                   0
#
#        MOVEMENT_CODE_Stopped in Traffic Lane  TIME_PERIOD_AFTERNOON  \
# 29588                                      0                      1
# 29589                                      0                      0
# 29590                                      0                      0
# 29591                                      0                      0
# 29592                                      0                      0
#
#        TIME_PERIOD_DAWN  TIME_PERIOD_EVENING  TIME_PERIOD_MORNING
# 29588                 0                    0                    0
# 29589                 0                    1                    0
# 29590                 0                    1                    0
# 29591                 0                    1                    0
# 29592                 1                    0                    0

# %%
scaled_df.columns
# Out:
# Index(['AGE', 'CONDITION_CODE_Alchol/Drug', 'CONDITION_CODE_Apparently Normal',
#        'CONDITION_CODE_Asleep',
#        'CONDITION_CODE_Emotional Depressed Angry Disturbed',
#        'CONDITION_CODE_Ill', 'CONDITION_CODE_Other Handicaps',
#        'EQUIP_PROB_CODE_Misuse', 'EQUIP_PROB_CODE_No Misuse',
#        'SAF_EQUIP_CODE_Belt',
#        ...
#        'MOVEMENT_CODE_Right Turn on Red', 'MOVEMENT_CODE_Skidding',
#        'MOVEMENT_CODE_Slowing or Stopping', 'MOVEMENT_CODE_Starting From Lane',
#        'MOVEMENT_CODE_Starting From Parked',
#        'MOVEMENT_CODE_Stopped in Traffic Lane', 'TIME_PERIOD_AFTERNOON',
#        'TIME_PERIOD_DAWN', 'TIME_PERIOD_EVENING', 'TIME_PERIOD_MORNING'],
#       dtype='object', length=102)

# %%
scaled_df.to_pickle("preprocessed_df")

# %% [markdown]
# # 적정 클러스터 개수

# %%
from scipy.cluster.hierarchy import linkage
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram

# %%
z = linkage(scaled_df, 'ward')

# %%
def plot_dendrogram(title, xlabel, ylabel, Z, max_d=None, p=None):
    # Settings for figure
    plt.figure(figsize=(25, 10))
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    # Dendrogram
    if p:
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
            truncate_mode = 'lastp',
            p=p,
            show_contracted = True
        )
    else:
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=8.,  # font size for the x axis labels
        )
    
    if max_d:
        plt.axhline(y=max_d, c='k')
    plt.show()

# %%
plot_dendrogram("Dendrogram", "Index", "Distance", z, p = 10, max_d = 110)

# %%
from scipy.cluster.hierarchy import fcluster
#120
predicted_labels = fcluster(z, 120, criterion = 'distance') 
predicted_labels # 0부터가 아니라 1부터 시작함. sklearn과 다름
set(predicted_labels)
# Out:
# {1, 2, 3, 4}

# %%
result_df = scaled_df.copy()
result_df['scipy_hc_labels'] = predicted_labels
result_df.tail()
# Out:
#             AGE  CONDITION_CODE_Alchol/Drug  CONDITION_CODE_Apparently Normal  \
# 29588  0.771133                           0                                 0
# 29589 -0.109788                           1                                 0
# 29590 -0.676095                           1                                 0
# 29591  0.896979                           1                                 0
# 29592 -0.298557                           1                                 0
#
#        CONDITION_CODE_Asleep  \
# 29588                      1
# 29589                      0
# 29590                      0
# 29591                      0
# 29592                      0
#
#        CONDITION_CODE_Emotional Depressed Angry Disturbed  CONDITION_CODE_Ill  \
# 29588                                                  0                    0
# 29589                                                  0                    0
# 29590                                                  0                    0
# 29591                                                  0                    0
# 29592                                                  0                    0
#
#        CONDITION_CODE_Other Handicaps  EQUIP_PROB_CODE_Misuse  \
# 29588                               0                       0
# 29589                               0                       0
# 29590                               0                       0
# 29591                               0                       0
# 29592                               0                       1
#
#        EQUIP_PROB_CODE_No Misuse  SAF_EQUIP_CODE_Belt  \
# 29588                          1                    1
# 29589                          1                    1
# 29590                          1                    1
# 29591                          1                    1
# 29592                          0                    1
#
#        SAF_EQUIP_CODE_Child System  SAF_EQUIP_CODE_Lighting  \
# 29588                            0                        0
# 29589                            0                        0
# 29590                            0                        0
# 29591                            0                        0
# 29592                            0                        0
#
#        SAF_EQUIP_CODE_MC/Bike  SAF_EQUIP_CODE_None    \
# 29588                       0                      0
# 29589                       0                      0
# 29590                       0                      0
# 29591                       0                      0
# 29592                       0                      0
#
#        COLLISION_TYPE_CODE_Angle Meets  COLLISION_TYPE_CODE_Head On  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        COLLISION_TYPE_CODE_Opposite Direction  \
# 29588                                       0
# 29589                                       0
# 29590                                       0
# 29591                                       0
# 29592                                       0
#
#        COLLISION_TYPE_CODE_Same Direction Rear End  \
# 29588                                            0
# 29589                                            0
# 29590                                            1
# 29591                                            0
# 29592                                            0
#
#        COLLISION_TYPE_CODE_Same Direction Sideswipe  \
# 29588                                             0
# 29589                                             0
# 29590                                             0
# 29591                                             0
# 29592                                             0
#
#        COLLISION_TYPE_CODE_Same Direction/Turn  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Same Movement Angle  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Single Vehicle   JUNCTION_CODE_Alley  \
# 29588                                    1                    0
# 29589                                    1                    0
# 29590                                    0                    0
# 29591                                    1                    0
# 29592                                    1                    0
#
#        JUNCTION_CODE_Commercial Driveway  JUNCTION_CODE_Crossover Related  \
# 29588                                  0                                0
# 29589                                  0                                0
# 29590                                  0                                0
# 29591                                  0                                0
# 29592                                  0                                0
#
#        JUNCTION_CODE_Interchange Related  JUNCTION_CODE_Intersection  \
# 29588                                  0                           1
# 29589                                  0                           0
# 29590                                  0                           0
# 29591                                  0                           0
# 29592                                  0                           0
#
#        JUNCTION_CODE_Intersection Related  JUNCTION_CODE_Non Intersection  \
# 29588                                   0                               0
# 29589                                   0                               1
# 29590                                   0                               1
# 29591                                   0                               1
# 29592                                   0                               1
#
#        JUNCTION_CODE_Railway Grade Crossing  \
# 29588                                     0
# 29589                                     0
# 29590                                     0
# 29591                                     0
# 29592                                     0
#
#        JUNCTION_CODE_Residential Driveway  LANE_CODE_Acceleration Lane  \
# 29588                                   0                            1
# 29589                                   0                            0
# 29590                                   0                            1
# 29591                                   0                            0
# 29592                                   0                            0
#
#        LANE_CODE_Crossover Area  LANE_CODE_Deceleration Lane  \
# 29588                         0                            0
# 29589                         0                            0
# 29590                         0                            0
# 29591                         0                            0
# 29592                         0                            0
#
#        LANE_CODE_Left Turn Lane  LANE_CODE_Right Turn Lane  \
# 29588                         0                          0
# 29589                         0                          1
# 29590                         0                          0
# 29591                         0                          1
# 29592                         0                          1
#
#        LANE_CODE_Separator  LANE_CODE_Shoulder Area  \
# 29588                    0                        0
# 29589                    0                        0
# 29590                    0                        0
# 29591                    0                        0
# 29592                    0                        0
#
#        LIGHT_CODE_Dark - Unknown Lighting  LIGHT_CODE_Dark Lights On  \
# 29588                                   0                          0
# 29589                                   0                          1
# 29590                                   0                          0
# 29591                                   0                          0
# 29592                                   0                          1
#
#        LIGHT_CODE_Dark No Lights  LIGHT_CODE_Dawn  LIGHT_CODE_Daylight  \
# 29588                          0                0                    1
# 29589                          0                0                    0
# 29590                          0                0                    0
# 29591                          1                0                    0
# 29592                          0                0                    0
#
#        LIGHT_CODE_Dusk  RD_COND_CODE_Foreign Material  \
# 29588                0                              0
# 29589                0                              0
# 29590                1                              0
# 29591                0                              0
# 29592                0                              0
#
#        RD_COND_CODE_Holes, Ruts, Etc.  RD_COND_CODE_Loose Surface Material  \
# 29588                               0                                    0
# 29589                               0                                    0
# 29590                               0                                    0
# 29591                               0                                    1
# 29592                               0                                    0
#
#        RD_COND_CODE_No Defects  RD_COND_CODE_Obstruction Not Lighted  \
# 29588                        1                                     0
# 29589                        1                                     0
# 29590                        1                                     0
# 29591                        0                                     0
# 29592                        1                                     0
#
#        RD_COND_CODE_Obstruction Not Signaled  RD_COND_CODE_Shoulder Defect  \
# 29588                                      0                             0
# 29589                                      0                             0
# 29590                                      0                             0
# 29591                                      0                             0
# 29592                                      0                             0
#
#        RD_COND_CODE_View Obstructed  RD_DIV_CODE_One-way Trafficway  \
# 29588                             0                               0
# 29589                             0                               0
# 29590                             0                               0
# 29591                             0                               0
# 29592                             0                               0
#
#        RD_DIV_CODE_Two-way, Divided, Positive Median Barrier  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  1
# 29591                                                  0
# 29592                                                  1
#
#        RD_DIV_CODE_Two-way, Divided, Unprotected (painted >4 feet) Median  \
# 29588                                                  0
# 29589                                                  1
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        RD_DIV_CODE_Two-way, Not Divided  \
# 29588                                 1
# 29589                                 0
# 29590                                 0
# 29591                                 1
# 29592                                 0
#
#        RD_DIV_CODE_Two-way, Not Divided with a Continuous Left Turn Lane  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        SURF_COND_CODE_Dry  SURF_COND_CODE_Others  SURF_COND_CODE_Wet  \
# 29588                   1                      0                   0
# 29589                   1                      0                   0
# 29590                   1                      0                   0
# 29591                   0                      1                   0
# 29592                   1                      0                   0
#
#        SURF_COND_CODE_Winter  WEATHER_CODE_Blowing Sand, Soil, Dirt  \
# 29588                      0                                      0
# 29589                      0                                      0
# 29590                      0                                      0
# 29591                      0                                      0
# 29592                      0                                      0
#
#        WEATHER_CODE_Clear  WEATHER_CODE_Foggy  WEATHER_CODE_Raining  \
# 29588                   1                   0                     0
# 29589                   1                   0                     0
# 29590                   1                   0                     0
# 29591                   1                   0                     0
# 29592                   1                   0                     0
#
#        WEATHER_CODE_Severe Winds  WEATHER_CODE_Snow  \
# 29588                          0                  0
# 29589                          0                  0
# 29590                          0                  0
# 29591                          0                  0
# 29592                          0                  0
#
#        AREA_DAMAGED_CODE_MAIN_Front  AREA_DAMAGED_CODE_MAIN_Rear  \
# 29588                             1                            0
# 29589                             1                            0
# 29590                             1                            0
# 29591                             1                            0
# 29592                             1                            0
#
#        AREA_DAMAGED_CODE_MAIN_Side  BODY_TYPE_CODE_Bus  BODY_TYPE_CODE_Farm  \
# 29588                            0                   0                    0
# 29589                            0                   0                    0
# 29590                            0                   0                    0
# 29591                            0                   0                    0
# 29592                            0                   0                    0
#
#        BODY_TYPE_CODE_Motorcycle  BODY_TYPE_CODE_Passenger Car  \
# 29588                          0                             1
# 29589                          0                             1
# 29590                          0                             1
# 29591                          0                             1
# 29592                          0                             1
#
#        BODY_TYPE_CODE_Recreational  BODY_TYPE_CODE_Special/Emergency  \
# 29588                            0                                 0
# 29589                            0                                 0
# 29590                            0                                 0
# 29591                            0                                 0
# 29592                            0                                 0
#
#        BODY_TYPE_CODE_Special/Non Emergency  BODY_TYPE_CODE_Truck  \
# 29588                                     0                     0
# 29589                                     0                     0
# 29590                                     0                     0
# 29591                                     0                     0
# 29592                                     0                     0
#
#        MOVEMENT_CODE_Accelerating  MOVEMENT_CODE_Backing  \
# 29588                           0                      0
# 29589                           0                      0
# 29590                           0                      0
# 29591                           0                      0
# 29592                           0                      0
#
#        MOVEMENT_CODE_Changing Lanes  MOVEMENT_CODE_Driverless Moving Vehicle  \
# 29588                             0                                        0
# 29589                             0                                        0
# 29590                             0                                        0
# 29591                             0                                        0
# 29592                             0                                        0
#
#        MOVEMENT_CODE_Entering Traffic Lane  \
# 29588                                    0
# 29589                                    0
# 29590                                    0
# 29591                                    0
# 29592                                    0
#
#        MOVEMENT_CODE_Leaving Traffic Lane  MOVEMENT_CODE_Making Left Turn  \
# 29588                                   0                               0
# 29589                                   0                               0
# 29590                                   0                               0
# 29591                                   0                               0
# 29592                                   0                               0
#
#        MOVEMENT_CODE_Making Right Turn  MOVEMENT_CODE_Making U Turn  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        MOVEMENT_CODE_Moving Constant Speed  MOVEMENT_CODE_Negotiating a Curve  \
# 29588                                    1                                  0
# 29589                                    1                                  0
# 29590                                    0                                  0
# 29591                                    1                                  0
# 29592                                    1                                  0
#
#        MOVEMENT_CODE_Parked    MOVEMENT_CODE_Parking    MOVEMENT_CODE_Passing  \
# 29588                       0                        0                      0
# 29589                       0                        0                      0
# 29590                       0                        0                      0
# 29591                       0                        0                      0
# 29592                       0                        0                      0
#
#        MOVEMENT_CODE_Right Turn on Red  MOVEMENT_CODE_Skidding  \
# 29588                                0                       0
# 29589                                0                       0
# 29590                                0                       0
# 29591                                0                       0
# 29592                                0                       0
#
#        MOVEMENT_CODE_Slowing or Stopping  MOVEMENT_CODE_Starting From Lane  \
# 29588                                  0                                 0
# 29589                                  0                                 0
# 29590                                  1                                 0
# 29591                                  0                                 0
# 29592                                  0                                 0
#
#        MOVEMENT_CODE_Starting From Parked  \
# 29588                                   0
# 29589                                   0
# 29590                                   0
# 29591                                   0
# 29592                                   0
#
#        MOVEMENT_CODE_Stopped in Traffic Lane  TIME_PERIOD_AFTERNOON  \
# 29588                                      0                      1
# 29589                                      0                      0
# 29590                                      0                      0
# 29591                                      0                      0
# 29592                                      0                      0
#
#        TIME_PERIOD_DAWN  TIME_PERIOD_EVENING  TIME_PERIOD_MORNING  \
# 29588                 0                    0                    0
# 29589                 0                    1                    0
# 29590                 0                    1                    0
# 29591                 0                    1                    0
# 29592                 1                    0                    0
#
#        scipy_hc_labels
# 29588                4
# 29589                4
# 29590                2
# 29591                4
# 29592                4

# %%
component_check_df = result_df.copy()
component_check_df["AGE"] = df["AGE"]
component_check_df.tail()
# Out:
#         AGE  CONDITION_CODE_Alchol/Drug  CONDITION_CODE_Apparently Normal  \
# 29588  28.0                           0                                 0
# 29589  42.0                           1                                 0
# 29590  51.0                           1                                 0
# 29591  26.0                           1                                 0
# 29592  45.0                           1                                 0
#
#        CONDITION_CODE_Asleep  \
# 29588                      1
# 29589                      0
# 29590                      0
# 29591                      0
# 29592                      0
#
#        CONDITION_CODE_Emotional Depressed Angry Disturbed  CONDITION_CODE_Ill  \
# 29588                                                  0                    0
# 29589                                                  0                    0
# 29590                                                  0                    0
# 29591                                                  0                    0
# 29592                                                  0                    0
#
#        CONDITION_CODE_Other Handicaps  EQUIP_PROB_CODE_Misuse  \
# 29588                               0                       0
# 29589                               0                       0
# 29590                               0                       0
# 29591                               0                       0
# 29592                               0                       1
#
#        EQUIP_PROB_CODE_No Misuse  SAF_EQUIP_CODE_Belt  \
# 29588                          1                    1
# 29589                          1                    1
# 29590                          1                    1
# 29591                          1                    1
# 29592                          0                    1
#
#        SAF_EQUIP_CODE_Child System  SAF_EQUIP_CODE_Lighting  \
# 29588                            0                        0
# 29589                            0                        0
# 29590                            0                        0
# 29591                            0                        0
# 29592                            0                        0
#
#        SAF_EQUIP_CODE_MC/Bike  SAF_EQUIP_CODE_None    \
# 29588                       0                      0
# 29589                       0                      0
# 29590                       0                      0
# 29591                       0                      0
# 29592                       0                      0
#
#        COLLISION_TYPE_CODE_Angle Meets  COLLISION_TYPE_CODE_Head On  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        COLLISION_TYPE_CODE_Opposite Direction  \
# 29588                                       0
# 29589                                       0
# 29590                                       0
# 29591                                       0
# 29592                                       0
#
#        COLLISION_TYPE_CODE_Same Direction Rear End  \
# 29588                                            0
# 29589                                            0
# 29590                                            1
# 29591                                            0
# 29592                                            0
#
#        COLLISION_TYPE_CODE_Same Direction Sideswipe  \
# 29588                                             0
# 29589                                             0
# 29590                                             0
# 29591                                             0
# 29592                                             0
#
#        COLLISION_TYPE_CODE_Same Direction/Turn  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Same Movement Angle  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Single Vehicle   JUNCTION_CODE_Alley  \
# 29588                                    1                    0
# 29589                                    1                    0
# 29590                                    0                    0
# 29591                                    1                    0
# 29592                                    1                    0
#
#        JUNCTION_CODE_Commercial Driveway  JUNCTION_CODE_Crossover Related  \
# 29588                                  0                                0
# 29589                                  0                                0
# 29590                                  0                                0
# 29591                                  0                                0
# 29592                                  0                                0
#
#        JUNCTION_CODE_Interchange Related  JUNCTION_CODE_Intersection  \
# 29588                                  0                           1
# 29589                                  0                           0
# 29590                                  0                           0
# 29591                                  0                           0
# 29592                                  0                           0
#
#        JUNCTION_CODE_Intersection Related  JUNCTION_CODE_Non Intersection  \
# 29588                                   0                               0
# 29589                                   0                               1
# 29590                                   0                               1
# 29591                                   0                               1
# 29592                                   0                               1
#
#        JUNCTION_CODE_Railway Grade Crossing  \
# 29588                                     0
# 29589                                     0
# 29590                                     0
# 29591                                     0
# 29592                                     0
#
#        JUNCTION_CODE_Residential Driveway  LANE_CODE_Acceleration Lane  \
# 29588                                   0                            1
# 29589                                   0                            0
# 29590                                   0                            1
# 29591                                   0                            0
# 29592                                   0                            0
#
#        LANE_CODE_Crossover Area  LANE_CODE_Deceleration Lane  \
# 29588                         0                            0
# 29589                         0                            0
# 29590                         0                            0
# 29591                         0                            0
# 29592                         0                            0
#
#        LANE_CODE_Left Turn Lane  LANE_CODE_Right Turn Lane  \
# 29588                         0                          0
# 29589                         0                          1
# 29590                         0                          0
# 29591                         0                          1
# 29592                         0                          1
#
#        LANE_CODE_Separator  LANE_CODE_Shoulder Area  \
# 29588                    0                        0
# 29589                    0                        0
# 29590                    0                        0
# 29591                    0                        0
# 29592                    0                        0
#
#        LIGHT_CODE_Dark - Unknown Lighting  LIGHT_CODE_Dark Lights On  \
# 29588                                   0                          0
# 29589                                   0                          1
# 29590                                   0                          0
# 29591                                   0                          0
# 29592                                   0                          1
#
#        LIGHT_CODE_Dark No Lights  LIGHT_CODE_Dawn  LIGHT_CODE_Daylight  \
# 29588                          0                0                    1
# 29589                          0                0                    0
# 29590                          0                0                    0
# 29591                          1                0                    0
# 29592                          0                0                    0
#
#        LIGHT_CODE_Dusk  RD_COND_CODE_Foreign Material  \
# 29588                0                              0
# 29589                0                              0
# 29590                1                              0
# 29591                0                              0
# 29592                0                              0
#
#        RD_COND_CODE_Holes, Ruts, Etc.  RD_COND_CODE_Loose Surface Material  \
# 29588                               0                                    0
# 29589                               0                                    0
# 29590                               0                                    0
# 29591                               0                                    1
# 29592                               0                                    0
#
#        RD_COND_CODE_No Defects  RD_COND_CODE_Obstruction Not Lighted  \
# 29588                        1                                     0
# 29589                        1                                     0
# 29590                        1                                     0
# 29591                        0                                     0
# 29592                        1                                     0
#
#        RD_COND_CODE_Obstruction Not Signaled  RD_COND_CODE_Shoulder Defect  \
# 29588                                      0                             0
# 29589                                      0                             0
# 29590                                      0                             0
# 29591                                      0                             0
# 29592                                      0                             0
#
#        RD_COND_CODE_View Obstructed  RD_DIV_CODE_One-way Trafficway  \
# 29588                             0                               0
# 29589                             0                               0
# 29590                             0                               0
# 29591                             0                               0
# 29592                             0                               0
#
#        RD_DIV_CODE_Two-way, Divided, Positive Median Barrier  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  1
# 29591                                                  0
# 29592                                                  1
#
#        RD_DIV_CODE_Two-way, Divided, Unprotected (painted >4 feet) Median  \
# 29588                                                  0
# 29589                                                  1
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        RD_DIV_CODE_Two-way, Not Divided  \
# 29588                                 1
# 29589                                 0
# 29590                                 0
# 29591                                 1
# 29592                                 0
#
#        RD_DIV_CODE_Two-way, Not Divided with a Continuous Left Turn Lane  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        SURF_COND_CODE_Dry  SURF_COND_CODE_Others  SURF_COND_CODE_Wet  \
# 29588                   1                      0                   0
# 29589                   1                      0                   0
# 29590                   1                      0                   0
# 29591                   0                      1                   0
# 29592                   1                      0                   0
#
#        SURF_COND_CODE_Winter  WEATHER_CODE_Blowing Sand, Soil, Dirt  \
# 29588                      0                                      0
# 29589                      0                                      0
# 29590                      0                                      0
# 29591                      0                                      0
# 29592                      0                                      0
#
#        WEATHER_CODE_Clear  WEATHER_CODE_Foggy  WEATHER_CODE_Raining  \
# 29588                   1                   0                     0
# 29589                   1                   0                     0
# 29590                   1                   0                     0
# 29591                   1                   0                     0
# 29592                   1                   0                     0
#
#        WEATHER_CODE_Severe Winds  WEATHER_CODE_Snow  \
# 29588                          0                  0
# 29589                          0                  0
# 29590                          0                  0
# 29591                          0                  0
# 29592                          0                  0
#
#        AREA_DAMAGED_CODE_MAIN_Front  AREA_DAMAGED_CODE_MAIN_Rear  \
# 29588                             1                            0
# 29589                             1                            0
# 29590                             1                            0
# 29591                             1                            0
# 29592                             1                            0
#
#        AREA_DAMAGED_CODE_MAIN_Side  BODY_TYPE_CODE_Bus  BODY_TYPE_CODE_Farm  \
# 29588                            0                   0                    0
# 29589                            0                   0                    0
# 29590                            0                   0                    0
# 29591                            0                   0                    0
# 29592                            0                   0                    0
#
#        BODY_TYPE_CODE_Motorcycle  BODY_TYPE_CODE_Passenger Car  \
# 29588                          0                             1
# 29589                          0                             1
# 29590                          0                             1
# 29591                          0                             1
# 29592                          0                             1
#
#        BODY_TYPE_CODE_Recreational  BODY_TYPE_CODE_Special/Emergency  \
# 29588                            0                                 0
# 29589                            0                                 0
# 29590                            0                                 0
# 29591                            0                                 0
# 29592                            0                                 0
#
#        BODY_TYPE_CODE_Special/Non Emergency  BODY_TYPE_CODE_Truck  \
# 29588                                     0                     0
# 29589                                     0                     0
# 29590                                     0                     0
# 29591                                     0                     0
# 29592                                     0                     0
#
#        MOVEMENT_CODE_Accelerating  MOVEMENT_CODE_Backing  \
# 29588                           0                      0
# 29589                           0                      0
# 29590                           0                      0
# 29591                           0                      0
# 29592                           0                      0
#
#        MOVEMENT_CODE_Changing Lanes  MOVEMENT_CODE_Driverless Moving Vehicle  \
# 29588                             0                                        0
# 29589                             0                                        0
# 29590                             0                                        0
# 29591                             0                                        0
# 29592                             0                                        0
#
#        MOVEMENT_CODE_Entering Traffic Lane  \
# 29588                                    0
# 29589                                    0
# 29590                                    0
# 29591                                    0
# 29592                                    0
#
#        MOVEMENT_CODE_Leaving Traffic Lane  MOVEMENT_CODE_Making Left Turn  \
# 29588                                   0                               0
# 29589                                   0                               0
# 29590                                   0                               0
# 29591                                   0                               0
# 29592                                   0                               0
#
#        MOVEMENT_CODE_Making Right Turn  MOVEMENT_CODE_Making U Turn  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        MOVEMENT_CODE_Moving Constant Speed  MOVEMENT_CODE_Negotiating a Curve  \
# 29588                                    1                                  0
# 29589                                    1                                  0
# 29590                                    0                                  0
# 29591                                    1                                  0
# 29592                                    1                                  0
#
#        MOVEMENT_CODE_Parked    MOVEMENT_CODE_Parking    MOVEMENT_CODE_Passing  \
# 29588                       0                        0                      0
# 29589                       0                        0                      0
# 29590                       0                        0                      0
# 29591                       0                        0                      0
# 29592                       0                        0                      0
#
#        MOVEMENT_CODE_Right Turn on Red  MOVEMENT_CODE_Skidding  \
# 29588                                0                       0
# 29589                                0                       0
# 29590                                0                       0
# 29591                                0                       0
# 29592                                0                       0
#
#        MOVEMENT_CODE_Slowing or Stopping  MOVEMENT_CODE_Starting From Lane  \
# 29588                                  0                                 0
# 29589                                  0                                 0
# 29590                                  1                                 0
# 29591                                  0                                 0
# 29592                                  0                                 0
#
#        MOVEMENT_CODE_Starting From Parked  \
# 29588                                   0
# 29589                                   0
# 29590                                   0
# 29591                                   0
# 29592                                   0
#
#        MOVEMENT_CODE_Stopped in Traffic Lane  TIME_PERIOD_AFTERNOON  \
# 29588                                      0                      1
# 29589                                      0                      0
# 29590                                      0                      0
# 29591                                      0                      0
# 29592                                      0                      0
#
#        TIME_PERIOD_DAWN  TIME_PERIOD_EVENING  TIME_PERIOD_MORNING  \
# 29588                 0                    0                    0
# 29589                 0                    1                    0
# 29590                 0                    1                    0
# 29591                 0                    1                    0
# 29592                 1                    0                    0
#
#        scipy_hc_labels
# 29588                4
# 29589                4
# 29590                2
# 29591                4
# 29592                4

# %%
for cluster in component_check_df['scipy_hc_labels'].unique():
    print(component_check_df['scipy_hc_labels'].value_counts())
    print("\ncluster",cluster,"\n")
    print(component_check_df[component_check_df['scipy_hc_labels'] == cluster].mean().sort_values(ascending=False)[:20])
# Out:
# 4    12139
# 1     6815
# 2     5987
# 3     4652
# Name: scipy_hc_labels, dtype: int64
#
# cluster 1
#
# AGE                                                      39.221570
# scipy_hc_labels                                           1.000000
# SAF_EQUIP_CODE_Belt                                       0.997359
# EQUIP_PROB_CODE_No Misuse                                 0.997212
# RD_COND_CODE_No Defects                                   0.974321
# CONDITION_CODE_Apparently Normal                          0.969332
# SURF_COND_CODE_Wet                                        0.859281
# BODY_TYPE_CODE_Passenger Car                              0.842847
# LANE_CODE_Right Turn Lane                                 0.685253
# WEATHER_CODE_Raining                                      0.668232
# AREA_DAMAGED_CODE_MAIN_Front                              0.592663
# JUNCTION_CODE_Non Intersection                            0.581805
# LIGHT_CODE_Daylight                                       0.542920
# MOVEMENT_CODE_Moving Constant Speed                       0.530594
# RD_DIV_CODE_Two-way, Not Divided                          0.434629
# RD_DIV_CODE_Two-way, Divided, Positive Median Barrier     0.375495
# TIME_PERIOD_AFTERNOON                                     0.334850
# COLLISION_TYPE_CODE_Single Vehicle                        0.325752
# COLLISION_TYPE_CODE_Same Direction Rear End               0.306090
# TIME_PERIOD_MORNING                                       0.298606
# dtype: float64
# 4    12139
# 1     6815
# 2     5987
# 3     4652
# Name: scipy_hc_labels, dtype: int64
#
# cluster 2
#
# AGE                                                      42.920160
# scipy_hc_labels                                           2.000000
# EQUIP_PROB_CODE_No Misuse                                 0.998330
# SAF_EQUIP_CODE_Belt                                       0.997996
# WEATHER_CODE_Clear                                        0.996826
# CONDITION_CODE_Apparently Normal                          0.996826
# RD_COND_CODE_No Defects                                   0.991649
# SURF_COND_CODE_Dry                                        0.984132
# COLLISION_TYPE_CODE_Same Direction Rear End               0.972774
# AREA_DAMAGED_CODE_MAIN_Rear                               0.913145
# BODY_TYPE_CODE_Passenger Car                              0.850175
# LIGHT_CODE_Daylight                                       0.695340
# JUNCTION_CODE_Non Intersection                            0.604309
# LANE_CODE_Right Turn Lane                                 0.556873
# RD_DIV_CODE_Two-way, Divided, Positive Median Barrier     0.537164
# MOVEMENT_CODE_Slowing or Stopping                         0.472190
# TIME_PERIOD_AFTERNOON                                     0.455821
# MOVEMENT_CODE_Stopped in Traffic Lane                     0.342409
# RD_DIV_CODE_Two-way, Not Divided                          0.286287
# LANE_CODE_Left Turn Lane                                  0.271922
# dtype: float64
# 4    12139
# 1     6815
# 2     5987
# 3     4652
# Name: scipy_hc_labels, dtype: int64
#
# cluster 4
#
# AGE                                                      32.952385
# scipy_hc_labels                                           4.000000
# EQUIP_PROB_CODE_No Misuse                                 0.994728
# RD_COND_CODE_No Defects                                   0.988632
# WEATHER_CODE_Clear                                        0.988137
# SAF_EQUIP_CODE_Belt                                       0.980559
# SURF_COND_CODE_Dry                                        0.959717
# CONDITION_CODE_Apparently Normal                          0.935250
# BODY_TYPE_CODE_Passenger Car                              0.827086
# AREA_DAMAGED_CODE_MAIN_Front                              0.724360
# LANE_CODE_Right Turn Lane                                 0.687866
# MOVEMENT_CODE_Moving Constant Speed                       0.640333
# LIGHT_CODE_Daylight                                       0.565450
# JUNCTION_CODE_Non Intersection                            0.525496
# RD_DIV_CODE_Two-way, Not Divided                          0.455721
# TIME_PERIOD_AFTERNOON                                     0.347805
# JUNCTION_CODE_Intersection                                0.335118
# RD_DIV_CODE_Two-way, Divided, Positive Median Barrier     0.334459
# COLLISION_TYPE_CODE_Single Vehicle                        0.283384
# TIME_PERIOD_EVENING                                       0.271604
# dtype: float64
# 4    12139
# 1     6815
# 2     5987
# 3     4652
# Name: scipy_hc_labels, dtype: int64
#
# cluster 3
#
# AGE                                                      57.395744
# scipy_hc_labels                                           3.000000
# SAF_EQUIP_CODE_Belt                                       0.998710
# EQUIP_PROB_CODE_No Misuse                                 0.998495
# WEATHER_CODE_Clear                                        0.997635
# RD_COND_CODE_No Defects                                   0.990972
# SURF_COND_CODE_Dry                                        0.978719
# CONDITION_CODE_Apparently Normal                          0.961952
# BODY_TYPE_CODE_Passenger Car                              0.838994
# LIGHT_CODE_Daylight                                       0.736887
# AREA_DAMAGED_CODE_MAIN_Front                              0.668745
# LANE_CODE_Right Turn Lane                                 0.610920
# MOVEMENT_CODE_Moving Constant Speed                       0.558040
# TIME_PERIOD_AFTERNOON                                     0.466036
# RD_DIV_CODE_Two-way, Not Divided                          0.458512
# JUNCTION_CODE_Intersection                                0.425193
# JUNCTION_CODE_Non Intersection                            0.417455
# RD_DIV_CODE_Two-way, Divided, Positive Median Barrier     0.368229
# AREA_DAMAGED_CODE_MAIN_Side                               0.321582
# TIME_PERIOD_MORNING                                       0.305460
# dtype: float64

# %%
pd.value_counts(result_df['scipy_hc_labels'].values, sort=False)
# Out:
# 1     6815
# 2     5987
# 3     4652
# 4    12139
# dtype: int64

# %%
result_df.tail()
# Out:
#             AGE  CONDITION_CODE_Alchol/Drug  CONDITION_CODE_Apparently Normal  \
# 29588  0.771133                           0                                 0
# 29589 -0.109788                           1                                 0
# 29590 -0.676095                           1                                 0
# 29591  0.896979                           1                                 0
# 29592 -0.298557                           1                                 0
#
#        CONDITION_CODE_Asleep  \
# 29588                      1
# 29589                      0
# 29590                      0
# 29591                      0
# 29592                      0
#
#        CONDITION_CODE_Emotional Depressed Angry Disturbed  CONDITION_CODE_Ill  \
# 29588                                                  0                    0
# 29589                                                  0                    0
# 29590                                                  0                    0
# 29591                                                  0                    0
# 29592                                                  0                    0
#
#        CONDITION_CODE_Other Handicaps  EQUIP_PROB_CODE_Misuse  \
# 29588                               0                       0
# 29589                               0                       0
# 29590                               0                       0
# 29591                               0                       0
# 29592                               0                       1
#
#        EQUIP_PROB_CODE_No Misuse  SAF_EQUIP_CODE_Belt  \
# 29588                          1                    1
# 29589                          1                    1
# 29590                          1                    1
# 29591                          1                    1
# 29592                          0                    1
#
#        SAF_EQUIP_CODE_Child System  SAF_EQUIP_CODE_Lighting  \
# 29588                            0                        0
# 29589                            0                        0
# 29590                            0                        0
# 29591                            0                        0
# 29592                            0                        0
#
#        SAF_EQUIP_CODE_MC/Bike  SAF_EQUIP_CODE_None    \
# 29588                       0                      0
# 29589                       0                      0
# 29590                       0                      0
# 29591                       0                      0
# 29592                       0                      0
#
#        COLLISION_TYPE_CODE_Angle Meets  COLLISION_TYPE_CODE_Head On  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        COLLISION_TYPE_CODE_Opposite Direction  \
# 29588                                       0
# 29589                                       0
# 29590                                       0
# 29591                                       0
# 29592                                       0
#
#        COLLISION_TYPE_CODE_Same Direction Rear End  \
# 29588                                            0
# 29589                                            0
# 29590                                            1
# 29591                                            0
# 29592                                            0
#
#        COLLISION_TYPE_CODE_Same Direction Sideswipe  \
# 29588                                             0
# 29589                                             0
# 29590                                             0
# 29591                                             0
# 29592                                             0
#
#        COLLISION_TYPE_CODE_Same Direction/Turn  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Same Movement Angle  \
# 29588                                        0
# 29589                                        0
# 29590                                        0
# 29591                                        0
# 29592                                        0
#
#        COLLISION_TYPE_CODE_Single Vehicle   JUNCTION_CODE_Alley  \
# 29588                                    1                    0
# 29589                                    1                    0
# 29590                                    0                    0
# 29591                                    1                    0
# 29592                                    1                    0
#
#        JUNCTION_CODE_Commercial Driveway  JUNCTION_CODE_Crossover Related  \
# 29588                                  0                                0
# 29589                                  0                                0
# 29590                                  0                                0
# 29591                                  0                                0
# 29592                                  0                                0
#
#        JUNCTION_CODE_Interchange Related  JUNCTION_CODE_Intersection  \
# 29588                                  0                           1
# 29589                                  0                           0
# 29590                                  0                           0
# 29591                                  0                           0
# 29592                                  0                           0
#
#        JUNCTION_CODE_Intersection Related  JUNCTION_CODE_Non Intersection  \
# 29588                                   0                               0
# 29589                                   0                               1
# 29590                                   0                               1
# 29591                                   0                               1
# 29592                                   0                               1
#
#        JUNCTION_CODE_Railway Grade Crossing  \
# 29588                                     0
# 29589                                     0
# 29590                                     0
# 29591                                     0
# 29592                                     0
#
#        JUNCTION_CODE_Residential Driveway  LANE_CODE_Acceleration Lane  \
# 29588                                   0                            1
# 29589                                   0                            0
# 29590                                   0                            1
# 29591                                   0                            0
# 29592                                   0                            0
#
#        LANE_CODE_Crossover Area  LANE_CODE_Deceleration Lane  \
# 29588                         0                            0
# 29589                         0                            0
# 29590                         0                            0
# 29591                         0                            0
# 29592                         0                            0
#
#        LANE_CODE_Left Turn Lane  LANE_CODE_Right Turn Lane  \
# 29588                         0                          0
# 29589                         0                          1
# 29590                         0                          0
# 29591                         0                          1
# 29592                         0                          1
#
#        LANE_CODE_Separator  LANE_CODE_Shoulder Area  \
# 29588                    0                        0
# 29589                    0                        0
# 29590                    0                        0
# 29591                    0                        0
# 29592                    0                        0
#
#        LIGHT_CODE_Dark - Unknown Lighting  LIGHT_CODE_Dark Lights On  \
# 29588                                   0                          0
# 29589                                   0                          1
# 29590                                   0                          0
# 29591                                   0                          0
# 29592                                   0                          1
#
#        LIGHT_CODE_Dark No Lights  LIGHT_CODE_Dawn  LIGHT_CODE_Daylight  \
# 29588                          0                0                    1
# 29589                          0                0                    0
# 29590                          0                0                    0
# 29591                          1                0                    0
# 29592                          0                0                    0
#
#        LIGHT_CODE_Dusk  RD_COND_CODE_Foreign Material  \
# 29588                0                              0
# 29589                0                              0
# 29590                1                              0
# 29591                0                              0
# 29592                0                              0
#
#        RD_COND_CODE_Holes, Ruts, Etc.  RD_COND_CODE_Loose Surface Material  \
# 29588                               0                                    0
# 29589                               0                                    0
# 29590                               0                                    0
# 29591                               0                                    1
# 29592                               0                                    0
#
#        RD_COND_CODE_No Defects  RD_COND_CODE_Obstruction Not Lighted  \
# 29588                        1                                     0
# 29589                        1                                     0
# 29590                        1                                     0
# 29591                        0                                     0
# 29592                        1                                     0
#
#        RD_COND_CODE_Obstruction Not Signaled  RD_COND_CODE_Shoulder Defect  \
# 29588                                      0                             0
# 29589                                      0                             0
# 29590                                      0                             0
# 29591                                      0                             0
# 29592                                      0                             0
#
#        RD_COND_CODE_View Obstructed  RD_DIV_CODE_One-way Trafficway  \
# 29588                             0                               0
# 29589                             0                               0
# 29590                             0                               0
# 29591                             0                               0
# 29592                             0                               0
#
#        RD_DIV_CODE_Two-way, Divided, Positive Median Barrier  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  1
# 29591                                                  0
# 29592                                                  1
#
#        RD_DIV_CODE_Two-way, Divided, Unprotected (painted >4 feet) Median  \
# 29588                                                  0
# 29589                                                  1
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        RD_DIV_CODE_Two-way, Not Divided  \
# 29588                                 1
# 29589                                 0
# 29590                                 0
# 29591                                 1
# 29592                                 0
#
#        RD_DIV_CODE_Two-way, Not Divided with a Continuous Left Turn Lane  \
# 29588                                                  0
# 29589                                                  0
# 29590                                                  0
# 29591                                                  0
# 29592                                                  0
#
#        SURF_COND_CODE_Dry  SURF_COND_CODE_Others  SURF_COND_CODE_Wet  \
# 29588                   1                      0                   0
# 29589                   1                      0                   0
# 29590                   1                      0                   0
# 29591                   0                      1                   0
# 29592                   1                      0                   0
#
#        SURF_COND_CODE_Winter  WEATHER_CODE_Blowing Sand, Soil, Dirt  \
# 29588                      0                                      0
# 29589                      0                                      0
# 29590                      0                                      0
# 29591                      0                                      0
# 29592                      0                                      0
#
#        WEATHER_CODE_Clear  WEATHER_CODE_Foggy  WEATHER_CODE_Raining  \
# 29588                   1                   0                     0
# 29589                   1                   0                     0
# 29590                   1                   0                     0
# 29591                   1                   0                     0
# 29592                   1                   0                     0
#
#        WEATHER_CODE_Severe Winds  WEATHER_CODE_Snow  \
# 29588                          0                  0
# 29589                          0                  0
# 29590                          0                  0
# 29591                          0                  0
# 29592                          0                  0
#
#        AREA_DAMAGED_CODE_MAIN_Front  AREA_DAMAGED_CODE_MAIN_Rear  \
# 29588                             1                            0
# 29589                             1                            0
# 29590                             1                            0
# 29591                             1                            0
# 29592                             1                            0
#
#        AREA_DAMAGED_CODE_MAIN_Side  BODY_TYPE_CODE_Bus  BODY_TYPE_CODE_Farm  \
# 29588                            0                   0                    0
# 29589                            0                   0                    0
# 29590                            0                   0                    0
# 29591                            0                   0                    0
# 29592                            0                   0                    0
#
#        BODY_TYPE_CODE_Motorcycle  BODY_TYPE_CODE_Passenger Car  \
# 29588                          0                             1
# 29589                          0                             1
# 29590                          0                             1
# 29591                          0                             1
# 29592                          0                             1
#
#        BODY_TYPE_CODE_Recreational  BODY_TYPE_CODE_Special/Emergency  \
# 29588                            0                                 0
# 29589                            0                                 0
# 29590                            0                                 0
# 29591                            0                                 0
# 29592                            0                                 0
#
#        BODY_TYPE_CODE_Special/Non Emergency  BODY_TYPE_CODE_Truck  \
# 29588                                     0                     0
# 29589                                     0                     0
# 29590                                     0                     0
# 29591                                     0                     0
# 29592                                     0                     0
#
#        MOVEMENT_CODE_Accelerating  MOVEMENT_CODE_Backing  \
# 29588                           0                      0
# 29589                           0                      0
# 29590                           0                      0
# 29591                           0                      0
# 29592                           0                      0
#
#        MOVEMENT_CODE_Changing Lanes  MOVEMENT_CODE_Driverless Moving Vehicle  \
# 29588                             0                                        0
# 29589                             0                                        0
# 29590                             0                                        0
# 29591                             0                                        0
# 29592                             0                                        0
#
#        MOVEMENT_CODE_Entering Traffic Lane  \
# 29588                                    0
# 29589                                    0
# 29590                                    0
# 29591                                    0
# 29592                                    0
#
#        MOVEMENT_CODE_Leaving Traffic Lane  MOVEMENT_CODE_Making Left Turn  \
# 29588                                   0                               0
# 29589                                   0                               0
# 29590                                   0                               0
# 29591                                   0                               0
# 29592                                   0                               0
#
#        MOVEMENT_CODE_Making Right Turn  MOVEMENT_CODE_Making U Turn  \
# 29588                                0                            0
# 29589                                0                            0
# 29590                                0                            0
# 29591                                0                            0
# 29592                                0                            0
#
#        MOVEMENT_CODE_Moving Constant Speed  MOVEMENT_CODE_Negotiating a Curve  \
# 29588                                    1                                  0
# 29589                                    1                                  0
# 29590                                    0                                  0
# 29591                                    1                                  0
# 29592                                    1                                  0
#
#        MOVEMENT_CODE_Parked    MOVEMENT_CODE_Parking    MOVEMENT_CODE_Passing  \
# 29588                       0                        0                      0
# 29589                       0                        0                      0
# 29590                       0                        0                      0
# 29591                       0                        0                      0
# 29592                       0                        0                      0
#
#        MOVEMENT_CODE_Right Turn on Red  MOVEMENT_CODE_Skidding  \
# 29588                                0                       0
# 29589                                0                       0
# 29590                                0                       0
# 29591                                0                       0
# 29592                                0                       0
#
#        MOVEMENT_CODE_Slowing or Stopping  MOVEMENT_CODE_Starting From Lane  \
# 29588                                  0                                 0
# 29589                                  0                                 0
# 29590                                  1                                 0
# 29591                                  0                                 0
# 29592                                  0                                 0
#
#        MOVEMENT_CODE_Starting From Parked  \
# 29588                                   0
# 29589                                   0
# 29590                                   0
# 29591                                   0
# 29592                                   0
#
#        MOVEMENT_CODE_Stopped in Traffic Lane  TIME_PERIOD_AFTERNOON  \
# 29588                                      0                      1
# 29589                                      0                      0
# 29590                                      0                      0
# 29591                                      0                      0
# 29592                                      0                      0
#
#        TIME_PERIOD_DAWN  TIME_PERIOD_EVENING  TIME_PERIOD_MORNING  \
# 29588                 0                    0                    0
# 29589                 0                    1                    0
# 29590                 0                    1                    0
# 29591                 0                    1                    0
# 29592                 1                    0                    0
#
#        scipy_hc_labels
# 29588                4
# 29589                4
# 29590                2
# 29591                4
# 29592                4

# %% [markdown]
# # Decesion Tree

# %%
X, y = result_df.drop('scipy_hc_labels', axis = 1), result_df['scipy_hc_labels']

# %%
from sklearn.tree import DecisionTreeClassifier

class_weight = 'balanced'
max_depth = 3

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 77, stratify = y)

# %%
# dt_model 
dt_model = DecisionTreeClassifier(class_weight = class_weight, max_depth = 3)

# %%
# fit to model
dt_model.fit(X = X_train, y = y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dt_model.predict(X = X_test)
# Out:
# array([4, 4, 4, ..., 1, 1, 2], dtype=int32)

# %%
dt_model.score(X = X_test, y = y_test)
# Out:
# 0.84741181240708208

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pred = dt_model.predict(X = X_test), y_true = y_test)
# Out:
# array([[1692,    2,    4,    6],
#        [  32, 1344,   71,   50],
#        [  27,    8, 1024,  104],
#        [ 123,   39,  663, 2210]])

# %% [markdown]
# # Visualization

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
with open('test_tree.dot', "w") as f:
    export_graphviz(dt_model, f, feature_names = X.columns)
    
with open('test_tree.dot', 'r') as f:
    dot_graph = f.read()

graphviz.Source(dot_graph)

# %% [markdown]
# # Clustered by K-modes

# %%
with open('clustered_data', 'rb') as f:
    clustered_data = pickle.load(f)

# %%
analyzing_df = df.copy()
analyzing_df['cluster'] = clustered_data.cluster
analyzing_df.to_pickle('analyzing_df')

# %%
analyzing_df.columns
# Out:
# Index(['CONDITION_CODE', 'EQUIP_PROB_CODE', 'SAF_EQUIP_CODE',
#        'COLLISION_TYPE_CODE', 'JUNCTION_CODE', 'LANE_CODE', 'LIGHT_CODE',
#        'RD_COND_CODE', 'RD_DIV_CODE', 'SURF_COND_CODE', 'WEATHER_CODE',
#        'AREA_DAMAGED_CODE_MAIN', 'BODY_TYPE_CODE', 'MOVEMENT_CODE', 'AGE',
#        'TIME_PERIOD', 'cluster'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(x = analyzing_df.cluster)
plt.title('Accident Counts per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Counts')

for p in ax.patches:
    counts = int(p.get_height())
    ax.text(p.get_x(), p.get_height()-1500,'{}'.format(counts), color="white", size=20, style = 'italic')

# %% [markdown]
# ### Cluster 간 feature별 차이비교

# %%
for column in list(analyzing_df.columns):
    plt.figure(figsize = (6, 4))
    ax = sns.countplot(y = column, hue = "cluster",
                       data= analyzing_df)
    
    plt.show()

# %% [markdown]
# > 클러스터별 차이를 발견할 수 있음. 이를 정책입안에 사용하자.

# %% [markdown]
# # Fatality별 사고비용 계산

# %%
fatality_applied_df = df.copy()

# %%
list(set(fatality_applied_df['INJ_SEVER_CODE']))
# Out:
# ['No Injury',
#  'Fatal Injury',
#  'Possible Incapacitating Injury',
#  'Non-incapacitating Injury',
#  'Incapacitating/Disabled Injury']

# %%
fatality_applied_df["Fatality_Cost"] = 1

# %%
fatality_applied_df.tail()
# Out:
#          REPORT_NO CDL_FLAG  \
# 29588  MCP2526000L        N
# 29589   AC2051000K        N
# 29590   ADI5630003        N
# 29591   HM0146000D        N
# 29592  MCP1519000S        N
#
#                                           CONDITION_CODE  EQUIP_PROB_CODE  \
# 29588                                  Apparently Asleep        No Misuse
# 29589  Influenced by Medications and/or Drugs and/or ...        No Misuse
# 29590  Influenced by Medications and/or Drugs and/or ...        No Misuse
# 29591  Influenced by Medications and/or Drugs and/or ...        No Misuse
# 29592  Influenced by Medications and/or Drugs and/or ...  Belt(s) Misused
#
#       FAULT_FLAG                  INJ_SEVER_CODE  \
# 29588          Y  Possible Incapacitating Injury
# 29589          Y                       No Injury
# 29590          Y                       No Injury
# 29591          Y                       No Injury
# 29592          Y  Possible Incapacitating Injury
#
#                                   PERSON_ID PERSON_TYPE        SAF_EQUIP_CODE  \
# 29588  e0715157-51da-4266-bfeb-9dbb80117fba           D  Shoulder/Lap Belt(s)
# 29589  15f07506-e12b-4b2a-aa31-44635150d1c2           D  Shoulder/Lap Belt(s)
# 29590  63529935-542d-4c69-af1f-1b3e49894090           D  Shoulder/Lap Belt(s)
# 29591  400dc255-6c26-4e47-9f75-920439556f0b           D  Shoulder/Lap Belt(s)
# 29592  6dbbc5b4-3922-4726-ae9f-d4140e986ea4           D  Shoulder/Lap Belt(s)
#
#       SEX_CODE                            VEHICLE_ID      COLLISION_TYPE_CODE  \
# 29588        M  40840738-5b3e-4c2f-b56c-430b6e2875a6          Single Vehicle
# 29589        M  fbbdb263-5979-4a02-bf49-88a840fd8e2e          Single Vehicle
# 29590        M  acfa1fcd-e286-4e64-ba2b-36894375ccc8  Same Direction Rear End
# 29591        M  1075765b-229c-478a-8d42-b4d41ec35309          Single Vehicle
# 29592        M  cec5b365-1040-4898-8943-fa9259c1189c          Single Vehicle
#
#       C_M_ZONE_FLAG     JUNCTION_CODE          LANE_CODE      LIGHT_CODE  \
# 29588             N      Intersection  Acceleration Lane        Daylight
# 29589             N  Non Intersection    Right Turn Lane  Dark Lights On
# 29590             N  Non Intersection  Acceleration Lane            Dusk
# 29591             N  Non Intersection    Right Turn Lane  Dark No Lights
# 29592             N  Non Intersection    Right Turn Lane  Dark Lights On
#
#                  RD_COND_CODE  \
# 29588              No Defects
# 29589              No Defects
# 29590              No Defects
# 29591  Loose Surface Material
# 29592              No Defects
#
#                                              RD_DIV_CODE     SURF_COND_CODE  \
# 29588                               Two-way, Not Divided                Dry
# 29589  Two-way, Divided, Unprotected (painted >4 feet...                Dry
# 29590          Two-way, Divided, Positive Median Barrier                Dry
# 29591                               Two-way, Not Divided  Mud, Dirt, Gravel
# 29592          Two-way, Divided, Positive Median Barrier                Dry
#
#       WEATHER_CODE AREA_DAMAGED_CODE_MAIN           BODY_TYPE_CODE  \
# 29588        Clear            One o'clock            Passenger Car
# 29589        Clear            One o'clock            Passenger Car
# 29590        Clear            One o'clock  (Sport) Utility Vehicle
# 29591        Clear            One o'clock  (Sport) Utility Vehicle
# 29592        Clear         Twelve o'clock            Passenger Car
#
#        DAMAGE_CODE HIT_AND_RUN_FLAG          MOVEMENT_CODE  \
# 29588    Disabling                N  Moving Constant Speed
# 29589    Disabling                N  Moving Constant Speed
# 29590  Superficial                N    Slowing or Stopping
# 29591    Disabling                Y  Moving Constant Speed
# 29592    Disabling                N  Moving Constant Speed
#
#                       TIME   AGE  Fatality_Cost
# 29588  2015-11-15 15:34:00  28.0              1
# 29589  2015-12-19 22:40:00  42.0              1
# 29590  2015-10-22 18:00:00  51.0              1
# 29591  2015-11-29 22:45:00  26.0              1
# 29592  2015-12-03 02:42:00  45.0              1

# %%
fatality_applied_df.loc[fatality_applied_df['INJ_SEVER_CODE'] == 'Fatal Injury', 'Fatality_Cost'] = 8000
fatality_applied_df.loc[fatality_applied_df['INJ_SEVER_CODE'] == 'Incapacitating/Disabled Injury', 'Fatality_Cost'] = 2500
fatality_applied_df.loc[fatality_applied_df['INJ_SEVER_CODE'] == 'Possible Incapacitating Injury', 'Fatality_Cost'] = 900
fatality_applied_df.loc[fatality_applied_df['INJ_SEVER_CODE'] == 'Non-incapacitating Injury', 'Fatality_Cost'] = 70

# %%
fatality_applied_df[fatality_applied_df.INJ_SEVER_CODE == "Fatal Injury"].tail()
# Out:
#          REPORT_NO CDL_FLAG     CONDITION_CODE EQUIP_PROB_CODE FAULT_FLAG  \
# 17403   CX01310008        N   Fatigued Fainted       No Misuse          Y
# 17673   AC1466000J        N  Had Been Drinking       No Misuse          Y
# 24505   DA2260000P        N  Apparently Normal       No Misuse          N
# 25537  MSP64690022        N  Apparently Normal       No Misuse          N
# 29392   ZK0206000K        N  Apparently Normal       No Misuse          N
#
#       INJ_SEVER_CODE                             PERSON_ID PERSON_TYPE  \
# 17403   Fatal Injury  2f3f2900-457e-4e56-9700-6c7bf03ee0de           D
# 17673   Fatal Injury  5416133b-be44-4e83-a59e-143a25def1b9           D
# 24505   Fatal Injury  9b418fd4-1ced-4b7b-a84b-6cdc86177928           D
# 25537   Fatal Injury  efee642c-b46f-4d2d-8404-82968a721540           D
# 29392   Fatal Injury  d3c30a44-bb4f-441a-8217-c6ea5d3ce8cb           D
#
#              SAF_EQUIP_CODE SEX_CODE                            VEHICLE_ID  \
# 17403  Shoulder/Lap Belt(s)        M  fa3b6cb7-4d55-4ec3-ac21-547d4ec19479
# 17673  Shoulder/Lap Belt(s)        F  bdd51129-6315-469b-8676-f1a9bcde07b8
# 24505         Lap Belt Only        M  c5bfcec6-5f61-4a70-b84c-f7f1f6ce6fcc
# 25537  Shoulder/Lap Belt(s)        M  9360e19a-5b06-4bac-b1e1-94704adc4431
# 29392  Shoulder/Lap Belt(s)        M  9a3b267f-88b2-4510-bd3d-239c4d319a04
#
#       COLLISION_TYPE_CODE C_M_ZONE_FLAG     JUNCTION_CODE        LANE_CODE  \
# 17403     Single Vehicle              N  Non Intersection  Right Turn Lane
# 17673             Head On             N  Non Intersection  Right Turn Lane
# 24505             Head On             N  Non Intersection  Right Turn Lane
# 25537   Head On Left Turn             N  Non Intersection  Right Turn Lane
# 29392             Head On             N  Non Intersection  Right Turn Lane
#
#            LIGHT_CODE RD_COND_CODE           RD_DIV_CODE SURF_COND_CODE  \
# 17403        Daylight   No Defects  Two-way, Not Divided            Dry
# 17673  Dark Lights On   No Defects  Two-way, Not Divided            Dry
# 24505        Daylight   No Defects  Two-way, Not Divided            Wet
# 25537            Dusk   No Defects  Two-way, Not Divided            Wet
# 29392        Daylight   No Defects  Two-way, Not Divided            Wet
#
#       WEATHER_CODE AREA_DAMAGED_CODE_MAIN BODY_TYPE_CODE DAMAGE_CODE  \
# 17403        Clear         Twelve o'clock  Passenger Car   Destroyed
# 17673        Clear         Eleven o'clock  Passenger Car   Destroyed
# 24505      Raining         Twelve o'clock  Passenger Car   Destroyed
# 25537      Raining            Ten o'clock            Van   Disabling
# 29392      Raining         Twelve o'clock   Pickup Truck   Destroyed
#
#       HIT_AND_RUN_FLAG          MOVEMENT_CODE                 TIME   AGE  \
# 17403                N  Moving Constant Speed  2015-08-23 13:58:00  65.0
# 17673                N    Negotiating a Curve  2015-10-31 22:31:00  47.0
# 24505                N    Slowing or Stopping  2015-11-19 12:48:00  67.0
# 25537                N  Moving Constant Speed  2015-11-30 16:55:00  77.0
# 29392                N    Slowing or Stopping  2015-10-17 11:18:00  63.0
#
#        Fatality_Cost
# 17403           8000
# 17673           8000
# 24505           8000
# 25537           8000
# 29392           8000

# %%
fatality_applied_df.to_pickle("fatality_applied_df")
